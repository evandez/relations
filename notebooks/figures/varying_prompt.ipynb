# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../..")

import numpy as np
import matplotlib.pyplot as plt
import os
from src import data
import json
from tqdm.auto import tqdm
from src.metrics import AggregateMetric
import logging

from src.utils import logging_utils
from src.utils.sweep_utils import read_sweep_results, relation_from_dict

# logging_utils.configure(level=logging.DEBUG)

# %%
##############################################
model_name = "gptj"
path = f"../../results/sweep_prompt/{model_name}"
##############################################

os.listdir(path)
# Out:
# ['person_occupation',
#  'landmark_in_country',
#  'country_capital_city',
#  'plays_pro_sport',
#  'city_in_country',
#  'food_from_country',
#  'occupation_gender',
#  'name_gender',
#  'country_language',
#  'object_superclass',
#  'landmark_on_continent',
#  'country_largest_city',
#  'verb_past_tense',
#  'name_birthplace',
#  'person_sport_position',
#  'adjective_superlative']

# %%
def parse_for_n(n_icl, relation_path):
    sweep_results = read_sweep_results(
        sweep_dir=f"{relation_path}/{str(n_icl)}",
    )
    relation = list(sweep_results.keys())[0]
    relation_results = relation_from_dict(sweep_results[relation])
    prompt_template = relation_results.trials[0].prompt_template
    faithfulness = np.array([
        trial.layers[0].result.betas[0].recall[0] 
        for trial in relation_results.trials
    ])
    efficacy = np.array([
        trial.layers[0].result.ranks[0].efficacy[0]
        for trial in relation_results.trials
    ])

    return prompt_template, faithfulness, efficacy

def parse_for_relation(relation = "country capital city"):
    relation_path = os.path.join(path, relation.replace(" ", "_"))
    relation_path = os.path.join(relation_path, os.listdir(relation_path)[0])
    n_icl_list = [int(x) for x in os.listdir(relation_path) if x.startswith("args") == False]
    n_icl_list.sort()
    
    faith_means, faith_stds = [], []
    eff_means, eff_stds = [], []
    prompt_templates = []

    for n_icl in n_icl_list:
        prompt_template, faithfulness, efficacy = parse_for_n(n_icl, relation_path)
        faith_means.append(np.mean(faithfulness))
        faith_stds.append(np.std(faithfulness))
        eff_means.append(np.mean(efficacy))
        eff_stds.append(np.std(efficacy))
        prompt_templates.append(prompt_template)
    
    faith_means = np.array(faith_means)
    faith_stds = np.array(faith_stds)
    eff_means = np.array(eff_means)
    eff_stds = np.array(eff_stds)
    
    return prompt_templates, faith_means, faith_stds, eff_means, eff_stds

# %%
prompt_templates, faith_means, faith_stds, eff_means, eff_stds = parse_for_relation(relation = "country capital city")

# %%
diff_faith = []
diff_eff = []

for relation in os.listdir(path):
    print("-------------------------")
    print(f"{relation=}")
    print("-------------------------")
    prompt_templates, faith_means, faith_stds, eff_means, eff_stds = parse_for_relation(
        relation=relation
    )

    for i in range(len(prompt_templates)):
        line = "& \\texttt{" + prompt_templates[i].replace('{}', '\{\}') + "} "
        line += f"& ${faith_means[i]:.2f} \pm {faith_stds[i]:.2f}$ "
        line += f"& ${eff_means[i]:.2f} \pm {eff_stds[i]:.2f}$ "
        line += "\\\\"
        print(line)

    for i in faith_means:
        diff_faith.append(i - faith_means[0])
    for i in eff_means:
        diff_eff.append(i - eff_means[0])
    
    print("\\hline")
# Out:
# -------------------------
# relation='person_occupation'
# -------------------------
# & \texttt{\{\} works professionally as a} & $0.41 \pm 0.08$ & $0.55 \pm 0.09$ \\
# & \texttt{\{\} works as a} & $0.44 \pm 0.11$ & $0.58 \pm 0.07$ \\
# & \texttt{By profession, \{\} is a} & $0.46 \pm 0.14$ & $0.58 \pm 0.08$ \\
# \hline
# -------------------------
# relation='landmark_in_country'
# -------------------------
# & \texttt{What country is \{\} in? It is in} & $0.27 \pm 0.10$ & $0.64 \pm 0.03$ \\
# & \texttt{\{\} is in the country of} & $0.31 \pm 0.08$ & $0.66 \pm 0.02$ \\
# \hline
# -------------------------
# relation='country_capital_city'
# -------------------------
# & \texttt{The capital of \{\} is} & $0.84 \pm 0.09$ & $0.94 \pm 0.04$ \\
# & \texttt{The capital of \{\} is the city of} & $0.87 \pm 0.08$ & $0.94 \pm 0.04$ \\
# & \texttt{The capital city of \{\} is} & $0.84 \pm 0.08$ & $0.94 \pm 0.04$ \\
# & \texttt{What is the capital of \{\}? It is the city of} & $0.87 \pm 0.07$ & $0.92 \pm 0.05$ \\
# \hline
# -------------------------
# relation='plays_pro_sport'
# -------------------------
# & \texttt{\{\} plays the sport of} & $0.78 \pm 0.07$ & $0.90 \pm 0.03$ \\
# & \texttt{\{\} plays professionally in the sport of} & $0.78 \pm 0.09$ & $0.90 \pm 0.03$ \\
# & \texttt{What sport does \{\} play? They play} & $0.81 \pm 0.06$ & $0.90 \pm 0.03$ \\
# \hline
# -------------------------
# relation='city_in_country'
# -------------------------
# & \texttt{\{\} is part of} & $0.45 \pm 0.11$ & $0.81 \pm 0.10$ \\
# & \texttt{\{\} is in the country of} & $0.51 \pm 0.10$ & $0.85 \pm 0.09$ \\
# & \texttt{\{\} is part of the country of} & $0.44 \pm 0.11$ & $0.86 \pm 0.06$ \\
# & \texttt{\{\} is located in the country of} & $0.45 \pm 0.08$ & $0.87 \pm 0.06$ \\
# \hline
# -------------------------
# relation='food_from_country'
# -------------------------
# & \texttt{\{\} originates from} & $0.41 \pm 0.14$ & $0.89 \pm 0.07$ \\
# & \texttt{What is the country of origin for \{\}? It originates from} & $0.44 \pm 0.10$ & $0.88 \pm 0.06$ \\
# & \texttt{\{\} is from the country of} & $0.48 \pm 0.12$ & $0.90 \pm 0.07$ \\
# & \texttt{\{\} originates from the country of} & $0.44 \pm 0.14$ & $0.88 \pm 0.06$ \\
# \hline
# -------------------------
# relation='occupation_gender'
# -------------------------
# & \texttt{What gender (men or women) are \{\} associated with? They are usually} & $0.90 \pm 0.09$ & $0.98 \pm 0.03$ \\
# & \texttt{Usually, what gender (men or women) are \{\}? They are typically} & $0.92 \pm 0.07$ & $0.99 \pm 0.03$ \\
# & \texttt{Is the profession of \{\} usually for men or women? It is usually for} & $0.88 \pm 0.09$ & $0.98 \pm 0.04$ \\
# & \texttt{\{\} are typically} & $1.00 \pm 0.00$ & $0.74 \pm 0.15$ \\
# \hline
# -------------------------
# relation='name_gender'
# -------------------------
# & \texttt{Is \{\} a name for a man or a woman? It is for a} & $0.61 \pm 0.09$ & $0.82 \pm 0.07$ \\
# & \texttt{Is the name \{\} usually for a man or woman? It's usually for a} & $0.62 \pm 0.06$ & $0.82 \pm 0.11$ \\
# & \texttt{\{\} is usually a name for a} & $0.70 \pm 0.22$ & $0.75 \pm 0.23$ \\
# & \texttt{What gender (man or woman) is the name \{\}? It's usually a} & $0.84 \pm 0.10$ & $0.90 \pm 0.06$ \\
# \hline
# -------------------------
# relation='country_language'
# -------------------------
# & \texttt{In \{\}, the primary language is} & $0.75 \pm 0.13$ & $0.97 \pm 0.04$ \\
# & \texttt{In \{\}, people speak the language of} & $0.83 \pm 0.10$ & $0.97 \pm 0.05$ \\
# & \texttt{The language used in \{\} is} & $0.70 \pm 0.14$ & $0.98 \pm 0.02$ \\
# & \texttt{People in \{\} speak} & $0.83 \pm 0.09$ & $0.96 \pm 0.04$ \\
# & \texttt{People in \{\} speak the language of} & $0.83 \pm 0.09$ & $0.99 \pm 0.02$ \\
# & \texttt{\{\}, where most people speak} & $0.62 \pm 0.14$ & $0.95 \pm 0.05$ \\
# \hline
# -------------------------
# relation='object_superclass'
# -------------------------
# & \texttt{A \{\} is in the category of a} & $0.85 \pm 0.05$ & $0.88 \pm 0.06$ \\
# & \texttt{What superclass (animal, bird, fish, vegetable, flower, fruit) is a \{\}? It is a} & $0.92 \pm 0.03$ & $0.92 \pm 0.04$ \\
# & \texttt{Is a \{\} a animal, bird, fish, vegetable, flower, or fruit? It is a} & $0.87 \pm 0.04$ & $0.89 \pm 0.05$ \\
# \hline
# -------------------------
# relation='landmark_on_continent'
# -------------------------
# & \texttt{What continent is \{\} on? It is on} & $0.53 \pm 0.16$ & $0.78 \pm 0.07$ \\
# & \texttt{\{\} is on the continent of} & $0.48 \pm 0.19$ & $0.77 \pm 0.07$ \\
# \hline
# -------------------------
# relation='country_largest_city'
# -------------------------
# & \texttt{The largest city in \{\} is the city of} & $0.91 \pm 0.05$ & $0.95 \pm 0.06$ \\
# & \texttt{What is the largest city in \{\}? It is the city of} & $0.88 \pm 0.05$ & $0.94 \pm 0.07$ \\
# & \texttt{The biggest city in \{\} is} & $0.88 \pm 0.07$ & $0.95 \pm 0.06$ \\
# & \texttt{The largest city in \{\} is} & $0.88 \pm 0.06$ & $0.95 \pm 0.05$ \\
# \hline
# -------------------------
# relation='verb_past_tense'
# -------------------------
# & \texttt{What is the past tense of \{\}? It is} & $0.92 \pm 0.07$ & $0.96 \pm 0.03$ \\
# & \texttt{The past tense of \{\} is} & $0.94 \pm 0.04$ & $0.95 \pm 0.04$ \\
# \hline
# -------------------------
# relation='name_birthplace'
# -------------------------
# & \texttt{\{\} was born in the country of} & $0.85 \pm 0.07$ & $0.85 \pm 0.09$ \\
# & \texttt{What country was \{\} most likely born in? They were born in} & $0.83 \pm 0.08$ & $0.87 \pm 0.07$ \\
# \hline
# -------------------------
# relation='person_sport_position'
# -------------------------
# & \texttt{In their sport, \{\} plays in the position of a} & $0.38 \pm 0.23$ & $0.59 \pm 0.13$ \\
# & \texttt{\{\} plays in the position of a} & $0.43 \pm 0.19$ & $0.58 \pm 0.11$ \\
# & \texttt{Which position does \{\} play? They play as a} & $0.46 \pm 0.15$ & $0.63 \pm 0.10$ \\
# & \texttt{In their sport, \{\} plays as a} & $0.39 \pm 0.13$ & $0.65 \pm 0.08$ \\
# \hline
# -------------------------
# relation='adjective_superlative'
# -------------------------
# & \texttt{The superlative form of \{\} is} & $0.93 \pm 0.02$ & $0.97 \pm 0.02$ \\
# & \texttt{What is the superlative form of \{\}? It is} & $0.92 \pm 0.02$ & $0.96 \pm 0.03$ \\
# \hline

# %%
np.array(diff_faith).mean(), np.array(diff_eff).mean()
# Out:
# (0.0183642867583407, 0.002540693583432121)
