# %% [markdown]
# <a href="https://colab.research.google.com/github/kmeng01/rome/blob/main/notebooks/causal_trace.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" align="left"/></a>&nbsp;or in a local notebook.

# %%
# %%bash
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
# cd /content && rm -rf /content/memit
# git clone https://github.com/kmeng01/memit memit > install.log 2>&1
# pip install -r /content/memit/scripts/colab_reqs/rome.txt >> install.log 2>&1
# pip install --upgrade google-cloud-storage >> install.log 2>&1

# %%
# IS_COLAB = False
# try:
#     import google.colab, torch, os

#     IS_COLAB = True
#     os.chdir("/content/memit")
#     if not torch.cuda.is_available():
#         raise Exception("Change runtime type to include a GPU.")
# except ModuleNotFoundError as _:
#     pass

# %% [markdown]
# ## Causal Tracing
#
# A demonstration of the double-intervention causal tracing method.
#
# The strategy used by causal tracing is to understand important
# states within a transfomer by doing two interventions simultaneously:
#
# 1. Corrupt a subset of the input.  In our paper, we corrupt the subject tokens
#    to frustrate the ability of the transformer to accurately complete factual
#    prompts about the subject.
# 2. Restore a subset of the internal hidden states.  In our paper, we scan
#    hidden states at all layers and all tokens, searching for individual states
#    that carry the necessary information for the transformer to recover its
#    capability to complete the factual prompt.
#
# The traces of decisive states can be shown on a heatmap.  This notebook
# demonstrates the code for conducting causal traces and creating these heatmaps.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# The `experiments.causal_trace` module contains a set of functions for running causal traces.
#
# In this notebook, we reproduce, demonstrate and discuss the interesting functions.
#
# We begin by importing several utility functions that deal with tokens and transformer models.

# %%
import os, re, json
import torch, numpy
from collections import defaultdict
from util import nethook
from util.globals import DATA_DIR
from experiments.causal_trace import (
    ModelAndTokenizer,
    layername,
    guess_subject,
    plot_trace_heatmap,
)
from experiments.causal_trace import (
    make_inputs,
    decode_tokens,
    find_token_range,
    predict_token,
    predict_from_input,
    collect_embedding_std,
)
from dsets import KnownsDataset

torch.set_grad_enabled(False)

# %% [markdown]
# Now we load a model and tokenizer, and show that it can complete a couple factual statements correctly.

# %%
model_name = "EleutherAI/gpt-j-6B"  # "gpt2-xl" or "EleutherAI/gpt-j-6B" or "EleutherAI/gpt-neox-20b"
mt = ModelAndTokenizer(
    model_name,
    low_cpu_mem_usage=True,
    # torch_dtype=(torch.float16 if "20b" in model_name else None),
    torch_dtype=torch.float16
)

model = mt.model
tokenizer = mt.tokenizer
tokenizer.pad_token = tokenizer.eos_token

# %%
predict_token(
    mt,
    ["Megan Rapinoe plays the sport of", "The Space Needle is in the city of"],
    return_p=True,
)
# Out:
# ([' soccer', ' Seattle'], tensor([0.6858, 0.9230], device='cuda:0'))

# %% [markdown]
# To obfuscate the subject during Causal Tracing, we use noise sampled from a zero-centered spherical Gaussian, whose stddev is 3 times the $\sigma$ stddev the model's embeddings. Let's compute that value.

# %%
knowns = KnownsDataset(DATA_DIR)  # Dataset of known facts
noise_level = 3 * collect_embedding_std(mt, [k["subject"] for k in knowns])
print(f"Using noise level {noise_level}")
# Out:
# Loaded dataset with 1209 elements
# Using noise level 0.0941162109375

# %% [markdown]
# ## Tracing a single location
#
# The core intervention in causal tracing is captured in this function:
#
# `trace_with_patch` a single causal trace.
#
# It enables running a batch of inferences with two interventions.
#
#   1. Random noise can be added to corrupt the inputs of some of the batch.
#   2. At any point, clean non-noised state can be copied over from an
#      uncorrupted batch member to other batch members.
#
# The convention used by this function is that the zeroth element of the
# batch is the uncorrupted run, and the subsequent elements of the batch
# are the corrupted runs.  The argument tokens_to_mix specifies an
# be corrupted by adding Gaussian noise to the embedding for the batch
# inputs other than the first element in the batch.  Alternately,
# subsequent runs could be corrupted by simply providing different
# input tokens via the passed input batch.
#
# To ensure that corrupted behavior is representative, in practice, we
# will actually run several (ten) corrupted runs in the same batch,
# each with its own sample of noise.
#
# Then when running, a specified set of hidden states will be uncorrupted
# by restoring their values to the same vector that they had in the
# zeroth uncorrupted run.  This set of hidden states is listed in
# states_to_patch, by listing [(token_index, layername), ...] pairs.
# To trace the effect of just a single state, this can be just a single
# token/layer pair.  To trace the effect of restoring a set of states,
# any number of token indices and layers can be listed.
#
# Note that this function is also in experiments.causal_trace; the code
# is shown here to show the logic.

# %%
def trace_with_patch(
    model,  # The model
    inp,  # A set of inputs
    states_to_patch,  # A list of (token index, layername) triples to restore
    answers_t,  # Answer probabilities to collect
    tokens_to_mix,  # Range of tokens to corrupt (begin, end)
    noise=0.1,  # Level of noise to add
    trace_layers=None,  # List of traced outputs to return
):
    prng = numpy.random.RandomState(1)  # For reproducibility, use pseudorandom noise
    patch_spec = defaultdict(list)
    for t, l in states_to_patch:
        patch_spec[l].append(t)
    embed_layername = layername(model, 0, "embed")

    def untuple(x):
        return x[0] if isinstance(x, tuple) else x

    # Define the model-patching rule.
    def patch_rep(x, layer):
        if layer == embed_layername:
            # If requested, we corrupt a range of token embeddings on batch items x[1:]
            if tokens_to_mix is not None:
                b, e = tokens_to_mix
                x[1:, b:e] += noise * torch.from_numpy(
                    prng.randn(x.shape[0] - 1, e - b, x.shape[2])
                ).to(x.device)
            return x
        if layer not in patch_spec:
            return x
        # If this layer is in the patch_spec, restore the uncorrupted hidden state
        # for selected tokens.
        h = untuple(x)
        for t in patch_spec[layer]:
            h[1:, t] = h[0, t]
        return x

    # With the patching rules defined, run the patched model in inference.
    additional_layers = [] if trace_layers is None else trace_layers
    with torch.no_grad(), nethook.TraceDict(
        model,
        [embed_layername] + list(patch_spec.keys()) + additional_layers,
        edit_output=patch_rep,
    ) as td:
        outputs_exp = model(**inp)

    # We report softmax probabilities for the answers_t token predictions of interest.
    probs = torch.softmax(outputs_exp.logits[1:, -1, :], dim=1).mean(dim=0)[answers_t]

    # If tracing all layers, collect all activations together to return.
    if trace_layers is not None:
        all_traced = torch.stack(
            [untuple(td[layer].output).detach().cpu() for layer in trace_layers], dim=2
        )
        return probs, all_traced

    return probs

# %% [markdown]
# ## Scanning all locations
#
# A causal flow heatmap is created by repeating `trace_with_patch` at every individual hidden state, and measuring the impact of restoring state at each location.
#
# The `calculate_hidden_flow` function does this loop.  It handles both the case of restoring a single hidden state, and also restoring MLP or attention states.  Because MLP and attention make small residual contributions, to observe a causal effect in those cases, we need to restore several layers of contributions at once, which is done by `trace_important_window`.

# %%
def calculate_hidden_flow(
    mt, prompt, subject, samples=10, noise=0.1, window=10, kind=None
):
    """
    Runs causal tracing over every token/layer combination in the network
    and returns a dictionary numerically summarizing the results.
    """
    inp = make_inputs(mt.tokenizer, [prompt] * (samples + 1))
    with torch.no_grad():
        answer_t, base_score = [d[0] for d in predict_from_input(mt.model, inp)]
    [answer] = decode_tokens(mt.tokenizer, [answer_t])
    e_range = find_token_range(mt.tokenizer, inp["input_ids"][0], subject)
    low_score = trace_with_patch(
        mt.model, inp, [], answer_t, e_range, noise=noise
    ).item()
    if not kind:
        differences = trace_important_states(
            mt.model, mt.num_layers, inp, e_range, answer_t, noise=noise
        )
    else:
        differences = trace_important_window(
            mt.model,
            mt.num_layers,
            inp,
            e_range,
            answer_t,
            noise=noise,
            window=window,
            kind=kind,
        )
    differences = differences.detach().cpu()
    return dict(
        scores=differences,
        low_score=low_score,
        high_score=base_score,
        input_ids=inp["input_ids"][0],
        input_tokens=decode_tokens(mt.tokenizer, inp["input_ids"][0]),
        subject_range=e_range,
        answer=answer,
        window=window,
        kind=kind or "",
    )


def trace_important_states(model, num_layers, inp, e_range, answer_t, noise=0.1):
    ntoks = inp["input_ids"].shape[1]
    table = []
    for tnum in range(ntoks):
        row = []
        for layer in range(0, num_layers):
            r = trace_with_patch(
                model,
                inp,
                [(tnum, layername(model, layer))],
                answer_t,
                tokens_to_mix=e_range,
                noise=noise,
            )
            row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)


def trace_important_window(
    model, num_layers, inp, e_range, answer_t, kind, window=10, noise=0.1
):
    ntoks = inp["input_ids"].shape[1]
    table = []
    for tnum in range(ntoks):
        row = []
        for layer in range(0, num_layers):
            layerlist = [
                (tnum, layername(model, L, kind))
                for L in range(
                    max(0, layer - window // 2), min(num_layers, layer - (-window // 2))
                )
            ]
            r = trace_with_patch(
                model, inp, layerlist, answer_t, tokens_to_mix=e_range, noise=noise
            )
            row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)

# %% [markdown]
# ## Plotting the results
#
# The `plot_trace_heatmap` function draws the data on a heatmap.  That function is not shown here; it is in `experiments.causal_trace`.

# %%
def plot_hidden_flow(
    mt,
    prompt,
    subject=None,
    samples=10,
    noise=0.1,
    window=10,
    kind=None,
    modelname=None,
    savepdf=None,
):
    if subject is None:
        subject = guess_subject(prompt)
    result = calculate_hidden_flow(
        mt, prompt, subject, samples=samples, noise=noise, window=window, kind=kind
    )
    plot_trace_heatmap(result, savepdf, modelname=modelname)


def plot_all_flow(mt, prompt, subject=None, noise=0.1, modelname=None):
    for kind in [None, "mlp", "attn"]:
        plot_hidden_flow(
            mt, prompt, subject, modelname=modelname, noise=noise, kind=kind
        )

# %% [markdown]
# The following prompt can be changed to any factual statement to trace.

# %%
plot_all_flow(mt, "The Space Needle is in the city of", noise=noise_level)

# %%
import sys
sys.path.append("..")

from util import model_utils

# %%
prompt = """ three comes after two
 six comes after five
 {} comes after"""

words = [ 'eleven', 'twelve', 'thirteen', 'fourteen']

# prompt = '''superlative of large is largest
#  superlative of quick is quickest
#  superlative of {} is'''

# words = ["tough", "safe"]

mt.tokenizer.pad_token = mt.tokenizer.eos_token
for w in words:
    txt, ret_dict = model_utils.generate_fast(
        mt.model, mt.tokenizer, 
        prompts=[prompt.format(w)], max_new_tokens=10, 
        get_answer_tokens=True, argmax_greedy=True
    )
    print(f"{w} ===> {ret_dict['answer'][0]['top_token']}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 15
#      13 mt.tokenizer.pad_token = mt.tokenizer.eos_token
#      14 for w in words:
# ---> 15     txt, ret_dict = model_utils.generate_fast(
#      16         mt.model, mt.tokenizer,
#      17         prompts=[prompt.format(w)], max_new_tokens=10,
#      18         get_answer_tokens=True, argmax_greedy=True
#      19     )
#      20     print(f"{w} ===> {ret_dict['answer'][0]['top_token']}")
#
# File ~/Codes/relations/notebooks/util/model_utils.py:115, in generate_fast(model, tok, prompts, top_k, max_out_len, max_new_tokens, argmax_greedy, debug, get_answer_tokens, track_interesting_words)
#     113 with torch.no_grad():
#     114     while input_ids.size(1) < max_out_len:  # while not exceeding max output length
# --> 115         model_out = model(
#     116             input_ids=input_ids[:, cur_context],
#     117             attention_mask=attention_mask[:, cur_context],
#     118             past_key_values=past_key_values,
#     119             use_cache=True,
#     120         )
#     121         logits, past_key_values = model_out.logits, model_out.past_key_values
#     122         # print(" ====> ", logits.shape)
#
# File ~/miniconda3/envs/relation/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/relation/lib/python3.10/site-packages/transformers/models/gptj/modeling_gptj.py:821, in GPTJForCausalLM.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#     813 r"""
#     814 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#     815     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#     816     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#     817     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#     818 """
#     819 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 821 transformer_outputs = self.transformer(
#     822     input_ids,
#     823     past_key_values=past_key_values,
#     824     attention_mask=attention_mask,
#     825     token_type_ids=token_type_ids,
#     826     position_ids=position_ids,
#     827     head_mask=head_mask,
#     828     inputs_embeds=inputs_embeds,
#     829     use_cache=use_cache,
#     830     output_attentions=output_attentions,
#     831     output_hidden_states=output_hidden_states,
#     832     return_dict=return_dict,
#     833 )
#     834 hidden_states = transformer_outputs[0]
#     836 # Set device for model parallelism
#
# File ~/miniconda3/envs/relation/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/relation/lib/python3.10/site-packages/transformers/models/gptj/modeling_gptj.py:622, in GPTJModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     619 head_mask = self.get_head_mask(head_mask, self.config.n_layer)
#     621 if inputs_embeds is None:
# --> 622     inputs_embeds = self.wte(input_ids)
#     624 hidden_states = inputs_embeds
#     626 if token_type_ids is not None:
#
# File ~/miniconda3/envs/relation/lib/python3.10/site-packages/torch/nn/modules/module.py:1151, in Module._call_impl(self, *input, **kwargs)
#    1149 if _global_forward_hooks or self._forward_hooks:
#    1150     for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
# -> 1151         hook_result = hook(self, input, result)
#    1152         if hook_result is not None:
#    1153             result = hook_result
#
# File ~/Codes/relations/notebooks/util/nethook.py:80, in Trace.__init__.<locals>.retain_hook(m, inputs, output)
#      73     retainer.input = recursive_copy(
#      74         inputs[0] if len(inputs) == 1 else inputs,
#      75         clone=clone,
#      76         detach=detach,
#      77         retain_grad=False,
#      78     )  # retain_grad applies to output only.
#      79 if edit_output:
# ---> 80     output = invoke_with_optional_args(
#      81         edit_output, output=output, layer=self.layer
#      82     )
#      83 if retain_output:
#      84     retainer.output = recursive_copy(
#      85         output, clone=clone, detach=detach, retain_grad=retain_grad
#      86     )
#
# File ~/Codes/relations/notebooks/util/nethook.py:451, in invoke_with_optional_args(fn, *args, **kwargs)
#     449 if argspec.varargs is not None:
#     450     pass_args += list(args[used_pos:])
# --> 451 return fn(*pass_args, **pass_kw)
#
# Cell In[8], line 25, in trace_with_patch.<locals>.patch_rep(x, layer)
#      23     if tokens_to_mix is not None:
#      24         b, e = tokens_to_mix
# ---> 25         x[1:, b:e] += noise * torch.from_numpy(
#      26             prng.randn(x.shape[0] - 1, e - b, x.shape[2])
#      27         ).to(x.device)
#      28     return x
#      29 if layer not in patch_spec:
#
# RuntimeError: output with shape [0, 1, 4096] doesn't match the broadcast shape [0, 4, 4096]

# %%
# prefix = "Megan Rapinoe plays the sport of"
# entity = "Megan Rapinoe"

entity = "eleven"
prefix = prompt.format(entity) 


plot_all_flow(mt, prompt=prefix, subject=entity, noise=noise_level)

# %% [markdown]
# Here we trace a few more factual statements from a file of test cases.

# %%
for knowledge in knowns[:5]:
    plot_all_flow(mt, knowledge["prompt"], knowledge["subject"], noise=noise_level)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 for knowledge in knowns[:5]:
# ----> 2     plot_all_flow(mt, knowledge["prompt"], knowledge["subject"], noise=noise_level)
#
# Cell In[10], line 22, in plot_all_flow(mt, prompt, subject, noise, modelname)
#      20 def plot_all_flow(mt, prompt, subject=None, noise=0.1, modelname=None):
#      21     for kind in [None, "mlp", "attn"]:
# ---> 22         plot_hidden_flow(
#      23             mt, prompt, subject, modelname=modelname, noise=noise, kind=kind
#      24         )
#
# Cell In[10], line 14, in plot_hidden_flow(mt, prompt, subject, samples, noise, window, kind, modelname, savepdf)
#      12 if subject is None:
#      13     subject = guess_subject(prompt)
# ---> 14 result = calculate_hidden_flow(
#      15     mt, prompt, subject, samples=samples, noise=noise, window=window, kind=kind
#      16 )
#      17 plot_trace_heatmap(result, savepdf, modelname=modelname)
#
# Cell In[9], line 21, in calculate_hidden_flow(mt, prompt, subject, samples, noise, window, kind)
#      17     differences = trace_important_states(
#      18         mt.model, mt.num_layers, inp, e_range, answer_t, noise=noise
#      19     )
#      20 else:
# ---> 21     differences = trace_important_window(
#      22         mt.model,
#      23         mt.num_layers,
#      24         inp,
#      25         e_range,
#      26         answer_t,
#      27         noise=noise,
#      28         window=window,
#      29         kind=kind,
#      30     )
#      31 differences = differences.detach().cpu()
#      32 return dict(
#      33     scores=differences,
#      34     low_score=low_score,
#    (...)
#      41     kind=kind or "",
#      42 )
#
# Cell In[9], line 78, in trace_important_window(model, num_layers, inp, e_range, answer_t, kind, window, noise)
#      71 for layer in range(0, num_layers):
#      72     layerlist = [
#      73         (tnum, layername(model, L, kind))
#      74         for L in range(
#      75             max(0, layer - window // 2), min(num_layers, layer - (-window // 2))
#      76         )
#      77     ]
# ---> 78     r = trace_with_patch(
#      79         model, inp, layerlist, answer_t, tokens_to_mix=e_range, noise=noise
#      80     )
#      81     row.append(r)
#      82 table.append(torch.stack(row))
#
# Cell In[8], line 40, in trace_with_patch(model, inp, states_to_patch, answers_t, tokens_to_mix, noise, trace_layers)
#      38 # With the patching rules defined, run the patched model in inference.
#      39 additional_layers = [] if trace_layers is None else trace_layers
# ---> 40 with torch.no_grad(), nethook.TraceDict(
#      41     model,
#      42     [embed_layername] + list(patch_spec.keys()) + additional_layers,
#      43     edit_output=patch_rep,
#      44 ) as td:
#      45     outputs_exp = model(**inp)
#      47 # We report softmax probabilities for the answers_t token predictions of interest.
#
# File ~/Codes/relations/notebooks/util/nethook.py:158, in TraceDict.__init__(self, module, layers, retain_output, retain_input, clone, detach, retain_grad, edit_output, stop)
#     155     yield True, prev
#     157 for is_last, layer in flag_last_unseen(layers):
# --> 158     self[layer] = Trace(
#     159         module=module,
#     160         layer=layer,
#     161         retain_output=retain_output,
#     162         retain_input=retain_input,
#     163         clone=clone,
#     164         detach=detach,
#     165         retain_grad=retain_grad,
#     166         edit_output=edit_output,
#     167         stop=stop and is_last,
#     168     )
#
# File ~/Codes/relations/notebooks/util/nethook.py:69, in Trace.__init__(self, module, layer, retain_output, retain_input, clone, detach, retain_grad, edit_output, stop)
#      67 self.layer = layer
#      68 if layer is not None:
# ---> 69     module = get_module(module, layer)
#      71 def retain_hook(m, inputs, output):
#      72     if retain_input:
#
# File ~/Codes/relations/notebooks/util/nethook.py:359, in get_module(model, name)
#     355 def get_module(model, name):
#     356     """
#     357     Finds the named module within the given model.
#     358     """
# --> 359     for n, m in model.named_modules():
#     360         if n == name:
#     361             return m
#
# File ~/miniconda3/envs/relation/lib/python3.10/site-packages/torch/nn/modules/module.py:1817, in Module.named_modules(self, memo, prefix, remove_duplicate)
#    1815     continue
#    1816 submodule_prefix = prefix + ('.' if prefix else '') + name
# -> 1817 for m in module.named_modules(memo, submodule_prefix, remove_duplicate):
#    1818     yield m
#
# File ~/miniconda3/envs/relation/lib/python3.10/site-packages/torch/nn/modules/module.py:1817, in Module.named_modules(self, memo, prefix, remove_duplicate)
#    1815     continue
#    1816 submodule_prefix = prefix + ('.' if prefix else '') + name
# -> 1817 for m in module.named_modules(memo, submodule_prefix, remove_duplicate):
#    1818     yield m
#
#     [... skipping similar frames: Module.named_modules at line 1817 (1 times)]
#
# File ~/miniconda3/envs/relation/lib/python3.10/site-packages/torch/nn/modules/module.py:1817, in Module.named_modules(self, memo, prefix, remove_duplicate)
#    1815     continue
#    1816 submodule_prefix = prefix + ('.' if prefix else '') + name
# -> 1817 for m in module.named_modules(memo, submodule_prefix, remove_duplicate):
#    1818     yield m
#
# KeyboardInterrupt:
