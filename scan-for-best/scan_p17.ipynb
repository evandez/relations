# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
import json
from tqdm import tqdm

# %%
import os
import sys
sys.path.append('..')

from relations import estimate
from util import model_utils
from dsets.counterfact import CounterFactDataset

# %%
MODEL_NAME = "gpt2-xl"  # gpt2-{medium,large,xl} or EleutherAI/gpt-j-6B
mt = model_utils.ModelAndTokenizer(MODEL_NAME, low_cpu_mem_usage=False)

model = mt.model
tokenizer = mt.tokenizer
tokenizer.pad_token = tokenizer.eos_token

# %%
subject_arr = [
    "The Space Needle",
    "The Eiffel Tower",
    "The Great Wall",
    "Niagara Falls",
    "Taj Mahal"
]

relation = "{} is located in the country of"

prompt = [relation.format(sub) for sub in subject_arr]

txt, ret_dict = model_utils.generate_fast(
    model, tokenizer,
    prompt,
    argmax_greedy = False,
    max_out_len= 20,
    # debug=True,
    get_answer_tokens=True,
)

model_utils.print_formatted_results(prompt, txt, ret_dict)
# Out:
# The Space Needle is located in the country of
# The Space Needle is located in the country of Seattle, in the city of Seattle. The Space
# p(answer):  p(' Washington'[2669])=0.1645, p(' Seattle'[7312])=0.106, p(' the'[262])=0.0764, p(' Japan'[2869])=0.0416, p(' Canada'[3340])=0.0377
#
# The Eiffel Tower is located in the country of
# The Eiffel Tower is located in the country of France. The Eiffel Tower is the
# p(answer):  p(' France'[4881])=0.9608, p(' Paris'[6342])=0.0046, p(' the'[262])=0.003, p(' Belgium'[15664])=0.0029, p(' French'[4141])=0.0029
#
# The Great Wall is located in the country of
# The Great Wall is located in the country of China, but is also part of the country's "
# p(answer):  p(' China'[2807])=0.4976, p(' the'[262])=0.0259, p(' Xin'[25426])=0.0201, p(' Yun'[20757])=0.015, p(' J'[449])=0.0141
#
# Niagara Falls is located in the country of
# Niagara Falls is located in the country of Ontario, in the province of Ontario.  The
# p(answer):  p(' Ontario'[10553])=0.3898, p(' Canada'[3340])=0.3671, p(' New'[968])=0.0784, p(' Quebec'[14778])=0.0155, p(' Newfoundland'[43867])=0.013
#
# Taj Mahal is located in the country of
# Taj Mahal is located in the country of India, which is known as Raj. The name
# p(answer):  p(' India'[3794])=0.404, p(' Oman'[41782])=0.0465, p(' Nepal'[27026])=0.0338, p(' Taj'[32490])=0.031, p(' Pakistan'[7648])=0.0285

# %%
is_located_in = estimate.estimate_relation_operator(
    model,
    tokenizer,
    "The Space Needle",
    "{} is located in the country of",
    layer=25,
    device=model.device,
)

is_located_in.misc
# Out:
# {'Jh_norm': 44.985111236572266,
#  'bias_norm': 372.6827087402344,
#  'h_info': {'h_index': 3, 'token_id': 293, 'token': 'le'},
#  'consider_residual': False}

# %%
is_located_in_res = estimate.estimate_relation_operator(
    model,
    tokenizer,
    "The Space Needle",
    "{} is located in the country of",
    layer=25,
    # consider_residual= True,
    # approximate_rank= 1,
    device=model.device,
    calculate_at_lnf= True,
)

is_located_in_res.misc
# Out:
# {'Jh_norm': 6.443312644958496,
#  'bias_norm': 13.347543716430664,
#  'h_info': {'h_index': 3, 'token_id': 293, 'token': 'le'},
#  'consider_residual': False}

# %%
test_cases = [
    ("The Great Wall", -1, "China"),
    ("Niagara Falls", -2, "Canada"),
    ("Valdemarsvik", -1, "Sweden"),
    ("Kyoto University", -2, "Japan"),
    ("Hattfjelldal", -1, "Norway"),
    ("Ginza", -1, "Japan"),
    ("Sydney Hospital", -2, "Australia"),
    ("Mahalangur Himal", -1, "Nepal"),
    ("Higashikagawa", -1, "Japan"),
    ("Trento", -1, "Italy"),
    ("Taj Mahal", -1, "India")
]

# %%
for subject, subject_token_index, target in test_cases:
    objects = is_located_in(
        subject,
        subject_token_index=subject_token_index,
        device=model.device,
        return_top_k=5,
    )
    print(f"{subject}, target: {target}   ==>   predicted: {objects}")
# Out:
# The Great Wall, target: China   ==>   predicted: [' China', ' Hong', ' Beijing', ' Chinese', ' Shen']
# Niagara Falls, target: Canada   ==>   predicted: [' Canada', ' Ontario', ' Niagara', ' New', ' British']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Iceland', ' Denmark', ' Sweden', ' Finland', ' Norway']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Japanese', ' Finland', ' Hawaii', ' Tokyo']
# Hattfjelldal, target: Norway   ==>   predicted: [' Iceland', ' Denmark', ' Norway', ' Sweden', ' Finland']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Singapore', ' China', ' Seattle', ' Hong']
# Sydney Hospital, target: Australia   ==>   predicted: [' Australia', ' Sydney', ' Australian', ' Singapore', ' Canberra']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Nepal', ' Tibet', ' Bh', ' Nep', ' China']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Japanese', ' Tokyo', ' Canada', ' Seattle']
# Trento, target: Italy   ==>   predicted: [' Sweden', ' Finland', ' Iceland', ' Denmark', ' Luxembourg']
# Taj Mahal, target: India   ==>   predicted: [' Iceland', ' Canada', ' Finland', ' Norway', ' New']

# %%
for subject, subject_token_index, target in test_cases:
    objects = is_located_in_res(
        subject,
        subject_token_index=subject_token_index,
        device=model.device,
        return_top_k=5,
    )
    print(f"{subject}, target: {target}   ==>   predicted: {objects}")
# Out:
# The Great Wall, target: China   ==>   predicted: [' China', ' Shen', ' Chinese', ' Qing', ' Beijing']
# Niagara Falls, target: Canada   ==>   predicted: [' Niagara', 'Toronto', ' Ontario', ' Cuomo', ' Erie']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Nordic', ' Greenland', 'vik', ' Swedish', ' Icelandic']
# Kyoto University, target: Japan   ==>   predicted: ['Japanese', ' Japanese', 'Tok', 'Japan', ' Japan']
# Hattfjelldal, target: Norway   ==>   predicted: [' Nordic', ' Denmark', ' Iceland', ' Scandinavian', ' Icelandic']
# Ginza, target: Japan   ==>   predicted: [' Tokyo', 'Tok', ' Japan', 'Japan', ' Japanese']
# Sydney Hospital, target: Australia   ==>   predicted: [' Sydney', ' NSW', ' Australia', ' Australian', 'Australia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Himal', ' Tibetan', ' Nepal', ' Nep', ' Tibet']
# Higashikagawa, target: Japan   ==>   predicted: [' Japanese', 'Japanese', ' Japan', ' Tokyo', 'Tok']
# Trento, target: Italy   ==>   predicted: ['meta', ' Budapest', ' Contra', 'Italy', ' Reno']
# Taj Mahal, target: India   ==>   predicted: [' Icelandic', ' Niagara', ' Iceland', ' sculpture', ' Hudson']

# %%
# operator = estimate.RelationOperator(
#         model = model, tokenizer= tokenizer,
#         layer = 25, relation = relation,
#         weight= is_located_in_res.weight, 
#         bias= is_located_in_res.bias,
#         consider_residual = True,
#     )

# for subject, subject_token_index, target in test_cases:
#     objects = operator(
#         subject,
#         subject_token_index=subject_token_index,
#         device=model.device,
#         return_top_k=5,
#     )
#     print(f"{subject}, target: {target}   ==>   predicted: {objects}")
# Out:
# The Great Wall, target: China   ==>   predicted: [' China', ' Japan', ' Russia', ' Kazakhstan', ' Mongolia']
# Niagara Falls, target: Canada   ==>   predicted: [' Sweden', ' Finland', ' Iceland', ' Canada', ' Denmark']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Denmark', ' Sweden', ' Finland', ' Iceland', ' Norway']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' China', ' Finland', ' Sweden', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Sweden', ' Iceland', ' Finland', ' Denmark', ' Norway']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' China', ' Finland', ' the', ' Sweden']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' China', ' Kazakhstan', ' Australia', ' Singapore']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' China', ' Kazakhstan', ' Bh', ' Japan', ' Iceland']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' China', ' the', ' Yuk', ' Washington']
# Trento, target: Italy   ==>   predicted: [' Sweden', ' the', ' Iceland', ' Denmark', ' Kazakhstan']
# Taj Mahal, target: India   ==>   predicted: [' Iceland', ' Sweden', ' Finland', ' Denmark', ' Bh']

# %%
# relation_operator = estimate.RelationOperator(
#     model = model, tokenizer= tokenizer,
#     layer = 20, relation = relation,
#     weight= is_located_in.weight, 
#     bias= is_located_in.bias
# )

# for subject, subject_token_index, target in test_cases:
#     objects = relation_operator(
#         subject,
#         subject_token_index=subject_token_index,
#         device=model.device,
#         return_top_k=5,
#     )
#     print(f"{subject}, target: {target}   ==>   predicted: {objects}")

# %%
########################################################
relation_id = "P17"
layer = 25
relation = "{} is located in the country of"
cache_path = "cached_jacobians"

consider_residual = True
approximate_rank = 3
#######################################################

# %%
# counterfact = CounterFactDataset("../data/")

# cf_relation = [c['requested_rewrite'] for c in counterfact if c["requested_rewrite"]["relation_id"] == relation_id]
# print("filtered >>> ", len(cf_relation))

# %%
# correct_predict = []

# for c in cf_relation:
#     print(c['subject'], " target: ", c['target_true']['str'], end = ", ")
#     txt, ret_dict = model_utils.generate_fast(
#         model, tokenizer,
#         [relation.format(c['subject'])],
#         argmax_greedy = True,
#         max_out_len= 20,
#         get_answer_tokens=True,
#     )
#     answer = ret_dict['answer'][0]['top_token']
#     print("predict: ", answer, end = " >>>> ")

#     ok = answer.strip() == c['target_true']['str']
#     print(ok)

#     if(ok):
#         correct_predict.append(c)

# with open(f"correct_prediction_{relation_id}__{MODEL_NAME}", "w") as f:
#     json.dump(correct_predict, f)

# %%
# for c in correct_predict:
#     print(c['subject'], " target: ", c['target_true']['str'])

# %%
with open(f"correct_prediction_{relation_id}__{MODEL_NAME}.json") as f:
    correct_predict = json.load(f)

# %%
calculated_relations = []

for c in tqdm(correct_predict):
    cur_calculation = estimate.estimate_relation_operator(
        model, tokenizer,
        c["subject"],
        relation,
        layer=layer,
        device=model.device,
        consider_residual = True,
        approximate_rank = approximate_rank
    )

    # print(cur_calculation.misc)

    calculated_relations.append({
        "subject": c["subject"],
        "request": c,
        "weight": cur_calculation.weight.cpu().numpy(),
        "bias": cur_calculation.bias.cpu().numpy(),
        "misc": cur_calculation.misc
    })
# Out:
# 100%|██████████| 266/266 [17:10<00:00,  3.87s/it]

# %%
np.savez(
    f"{cache_path}/residual_jacobian_calculations_{relation_id}__layer_{layer}__approx_rank_{approximate_rank}.npz", 
    jacobians = calculated_relations, 
    allow_pickle = True
)

# %%
# calculated_relations = np.load(f"jacobian_calculations_P17__layer_20.npz", allow_pickle = True)["jacobians"]

# %%
# weights_collection = [torch.tensor(t["weight"], device=model.device) for t in calculated_relations]
# bias_collection = [torch.tensor(t["bias"], device=model.device) for t in calculated_relations]

# %%
# weights = torch.stack(weights_collection).mean(dim = 0)
# bias = torch.stack(bias_collection).mean(dim = 0)

# %%
for calc in calculated_relations:
    print("zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz")
    print(f'(s = {calc["request"]["subject"]}, r = {relation} [{relation_id}], o = {calc["request"]["target_true"]["str"]})')
    print(calc["misc"])
    print("zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz")

    is_located_in = estimate.RelationOperator(
        model = model, tokenizer= tokenizer,
        layer = layer, relation = relation,
        weight= torch.tensor(calc['weight'], device = model.device), 
        bias= torch.tensor(calc['bias'], device=model.device),
        consider_residual = consider_residual,
    )

    for subject, subject_token_index, target in test_cases:
        objects = is_located_in(
            subject,
            subject_token_index=subject_token_index,
            device=model.device,
            return_top_k=5,
        )
        print(f"{subject}, target: {target}   ==>   predicted: {objects}")
    print()
    print()
# Out:
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Autonomous University of Madrid, r = {} is located in the country of [P17], o = Spain)
# {'Jh_norm': tensor(172.5770, device='cuda:0'), 'bias_norm': 394.9103088378906, 'h_info': {'h_index': 4, 'token_id': 14708, 'token': ' Madrid'}, 'consider_residual': (True, 3, tensor(43.3716, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Cast']
# Niagara Falls, target: Canada   ==>   predicted: [' Spain', ' And', ' the', ' Ar', ' Gran']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Ar']
# Kyoto University, target: Japan   ==>   predicted: [' Spain', ' the', ' And', ' Gran', ' Se']
# Hattfjelldal, target: Norway   ==>   predicted: [' And', ' Se', ' Spain', ' Ar', ' the']
# Ginza, target: Japan   ==>   predicted: [' Spain', ' And', ' the', ' Gran', ' Mall']
# Sydney Hospital, target: Australia   ==>   predicted: [' Spain', ' the', ' And', ' Gran', ' Portugal']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Spain', ' And', ' the', ' Gran', ' Val']
# Higashikagawa, target: Japan   ==>   predicted: [' Gran', ' Spain', ' And', ' Se', ' the']
# Trento, target: Italy   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Se']
# Taj Mahal, target: India   ==>   predicted: [' And', ' Spain', ' Gran', ' the', ' Ar']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Kuala Langat, r = {} is located in the country of [P17], o = Malaysia)
# {'Jh_norm': tensor(146.0664, device='cuda:0'), 'bias_norm': 413.4356689453125, 'h_info': {'h_index': 3, 'token_id': 265, 'token': 'at'}, 'consider_residual': (True, 3, tensor(40.1241, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Malaysia', ' Pen', ' B', ' Myanmar', ' West']
# Niagara Falls, target: Canada   ==>   predicted: [' Malaysia', ' B', ' Pakistan', ' Kir', ' Indonesia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Malaysia', ' Brune', ' B', ' Per', ' Sar']
# Kyoto University, target: Japan   ==>   predicted: [' Malaysia', ' Indonesia', ' B', ' Thailand', ' Kazakhstan']
# Hattfjelldal, target: Norway   ==>   predicted: [' B', ' Malaysia', ' Sar', ' the', ' K']
# Ginza, target: Japan   ==>   predicted: [' Malaysia', ' Singapore', ' Indonesia', ' B', ' Sab']
# Sydney Hospital, target: Australia   ==>   predicted: [' Malaysia', ' B', ' Perl', ' Indonesia', ' the']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' B', ' Malaysia', ' Thailand', ' Indonesia', ' Java']
# Higashikagawa, target: Japan   ==>   predicted: [' B', ' Sar', ' Malaysia', ' Sab', ' Kir']
# Trento, target: Italy   ==>   predicted: [' Malaysia', ' Kir', ' Sab', ' B', ' Sar']
# Taj Mahal, target: India   ==>   predicted: [' Malaysia', ' B', ' Sab', ' Indonesia', ' Bel']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Bastille, r = {} is located in the country of [P17], o = France)
# {'Jh_norm': tensor(161.0384, device='cuda:0'), 'bias_norm': 475.0666809082031, 'h_info': {'h_index': 2, 'token_id': 8270, 'token': 'ille'}, 'consider_residual': (True, 3, tensor(41.3258, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' France', ' Spain', ' Italy', ' Cors', ' the']
# Niagara Falls, target: Canada   ==>   predicted: [' France', ' Italy', ' the', ' Gen', ' F']
# Valdemarsvik, target: Sweden   ==>   predicted: [' France', ' the', ' T', ' Gaul', ' Bast']
# Kyoto University, target: Japan   ==>   predicted: [' France', ' the', ' Italy', ' Japan', ' T']
# Hattfjelldal, target: Norway   ==>   predicted: [' France', ' the', ' Brittany', ' Gaul', ' F']
# Ginza, target: Japan   ==>   predicted: [' France', ' Italy', ' the', ' Japan', ' Cors']
# Sydney Hospital, target: Australia   ==>   predicted: [' France', ' the', ' Georgia', ' Italy', ' Romania']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' France', ' the', ' T', ' San', ' Ireland']
# Higashikagawa, target: Japan   ==>   predicted: [' France', ' T', ' Italy', ' the', ' Gen']
# Trento, target: Italy   ==>   predicted: [' Italy', ' Cors', ' Spain', ' France', ' Catalonia']
# Taj Mahal, target: India   ==>   predicted: [' France', ' the', ' Italy', ' T', ' Jersey']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Valdemarsvik, r = {} is located in the country of [P17], o = Sweden)
# {'Jh_norm': tensor(153.8586, device='cuda:0'), 'bias_norm': 464.4398498535156, 'h_info': {'h_index': 4, 'token_id': 28930, 'token': 'vik'}, 'consider_residual': (True, 3, tensor(40.6221, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Sweden', ' Iceland', ' Russia', ' Norway', ' Denmark']
# Niagara Falls, target: Canada   ==>   predicted: [' Sweden', ' Latvia', ' the', ' Denmark', ' Iceland']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Sweden', ' Norway', ' Denmark', ' Iceland', ' Finland']
# Kyoto University, target: Japan   ==>   predicted: [' Sweden', ' Finland', ' the', ' Iceland', ' Denmark']
# Hattfjelldal, target: Norway   ==>   predicted: [' Sweden', ' Denmark', ' Iceland', ' the', ' Norway']
# Ginza, target: Japan   ==>   predicted: [' Sweden', ' Finland', ' Norway', ' Denmark', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' the', ' Belgium', ' France', ' Sweden', ' Georgia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Greenland', ' Iceland', ' Norway', ' Russia', ' the']
# Higashikagawa, target: Japan   ==>   predicted: [' the', ' Sweden', ' Iceland', ' Finland', ' Denmark']
# Trento, target: Italy   ==>   predicted: [' Sweden', ' Denmark', ' the', ' Estonia', ' Latvia']
# Taj Mahal, target: India   ==>   predicted: [' Sweden', ' the', ' Iceland', ' Denmark', ' Luxembourg']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Piper Verlag, r = {} is located in the country of [P17], o = Germany)
# {'Jh_norm': tensor(167.9637, device='cuda:0'), 'bias_norm': 407.2247009277344, 'h_info': {'h_index': 3, 'token_id': 30909, 'token': 'lag'}, 'consider_residual': (True, 3, tensor(40.1989, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Germany', ' East', ' West', ' South', ' Poland']
# Niagara Falls, target: Canada   ==>   predicted: [' Germany', ' the', ' South', ' Sw', ' Pr']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Germany', ' Norway', ' Poland', ' the', ' Denmark']
# Kyoto University, target: Japan   ==>   predicted: [' Germany', ' the', ' Pr', ' Sw', ' Nam']
# Hattfjelldal, target: Norway   ==>   predicted: [' Germany', ' the', ' Nam', ' Lie', ' Poland']
# Ginza, target: Japan   ==>   predicted: [' Germany', ' Nam', ' South', ' East', ' Pr']
# Sydney Hospital, target: Australia   ==>   predicted: [' the', ' Germany', ' Georgia', ' Sw', ' South']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' the', ' Germany', ' Pr', ' West', ' East']
# Higashikagawa, target: Japan   ==>   predicted: [' Germany', ' the', ' Nam', ' Japan', ' Bav']
# Trento, target: Italy   ==>   predicted: [' the', ' Lie', ' Germany', ' Lower', ' East']
# Taj Mahal, target: India   ==>   predicted: [' the', ' Germany', ' Austria', ' Nam', ' Bav']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Tehri Garhwal district, r = {} is located in the country of [P17], o = India)
# {'Jh_norm': tensor(178.1881, device='cuda:0'), 'bias_norm': 415.3458557128906, 'h_info': {'h_index': 6, 'token_id': 4783, 'token': ' district'}, 'consider_residual': (True, 3, tensor(39.9912, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' India', ' Afghanistan', ' China', ' J', ' And']
# Niagara Falls, target: Canada   ==>   predicted: [' India', ' Pakistan', ' the', ' Bh', ' Canada']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Bh', ' India', ' Nepal', ' the', ' J']
# Kyoto University, target: Japan   ==>   predicted: [' India', ' the', ' Afghanistan', ' China', ' J']
# Hattfjelldal, target: Norway   ==>   predicted: [' India', ' the', ' J', ' Bh', ' Nepal']
# Ginza, target: Japan   ==>   predicted: [' India', ' Pakistan', ' Bh', ' Nepal', ' Afghanistan']
# Sydney Hospital, target: Australia   ==>   predicted: [' India', ' the', ' Bh', ' Pakistan', ' Afghanistan']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' India', ' Nepal', ' Bh', ' Pakistan', ' the']
# Higashikagawa, target: Japan   ==>   predicted: [' India', ' J', ' Bh', ' Nepal', ' the']
# Trento, target: Italy   ==>   predicted: [' India', ' the', ' Iran', ' Afghanistan', ' Ch']
# Taj Mahal, target: India   ==>   predicted: [' India', ' Bh', ' Pakistan', ' Afghanistan', ' Nepal']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Darmstadt, r = {} is located in the country of [P17], o = Germany)
# {'Jh_norm': tensor(161.1846, device='cuda:0'), 'bias_norm': 392.8606262207031, 'h_info': {'h_index': 2, 'token_id': 38863, 'token': 'stadt'}, 'consider_residual': (True, 3, tensor(42.0051, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' the', ' West', ' Germany', ' Sa', ' Lower']
# Niagara Falls, target: Canada   ==>   predicted: [' the', ' Lower', ' Sw', ' Germany', ' Sax']
# Valdemarsvik, target: Sweden   ==>   predicted: [' the', ' Poland', ' Austria', ' Czech', ' Pr']
# Kyoto University, target: Japan   ==>   predicted: [' the', ' Pr', ' Sw', ' Germany', ' Lower']
# Hattfjelldal, target: Norway   ==>   predicted: [' the', ' Germany', ' Lower', ' Sax', ' Pr']
# Ginza, target: Japan   ==>   predicted: [' the', ' Lower', ' Pr', ' Germany', ' Bav']
# Sydney Hospital, target: Australia   ==>   predicted: [' the', ' Sw', ' Germany', ' Rh', ' South']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' the', ' Sax', ' Pr', ' Sa', ' Th']
# Higashikagawa, target: Japan   ==>   predicted: [' the', ' Lower', ' Pr', ' Bav', ' Germany']
# Trento, target: Italy   ==>   predicted: [' the', ' Lower', ' Sax', ' Sw', ' Germany']
# Taj Mahal, target: India   ==>   predicted: [' the', ' Sax', ' Lower', ' Bav', ' Pr']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Gazzola, r = {} is located in the country of [P17], o = Italy)
# {'Jh_norm': tensor(142.8901, device='cuda:0'), 'bias_norm': 494.00439453125, 'h_info': {'h_index': 2, 'token_id': 5708, 'token': 'ola'}, 'consider_residual': (True, 3, tensor(40.1240, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Italy', ' South', ' Spain', ' T', ' Georgia']
# Niagara Falls, target: Canada   ==>   predicted: [' South', ' Georgia', ' the', ' Italy', ' Croatia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Georgia', ' the', ' Macedonia', ' Romania', ' T']
# Kyoto University, target: Japan   ==>   predicted: [' Georgia', ' Italy', ' the', ' Japan', ' T']
# Hattfjelldal, target: Norway   ==>   predicted: [' the', ' Georgia', ' Poland', ' Romania', ' Slovenia']
# Ginza, target: Japan   ==>   predicted: [' Italy', ' South', ' Sard', ' the', ' T']
# Sydney Hospital, target: Australia   ==>   predicted: [' Georgia', ' the', ' South', ' Italy', ' Lebanon']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' the', ' Georgia', ' T', ' Italy', ' Albania']
# Higashikagawa, target: Japan   ==>   predicted: [' Georgia', ' the', ' T', ' Italy', ' Japan']
# Trento, target: Italy   ==>   predicted: [' Italy', ' Georgia', ' Albania', ' Sard', ' Cors']
# Taj Mahal, target: India   ==>   predicted: [' Italy', ' Malta', ' Georgia', ' the', ' Albania']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Borovsky District, r = {} is located in the country of [P17], o = Russia)
# {'Jh_norm': tensor(166.5450, device='cuda:0'), 'bias_norm': 535.2190551757812, 'h_info': {'h_index': 3, 'token_id': 5665, 'token': ' District'}, 'consider_residual': (True, 3, tensor(39.7627, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Russia', ' Ukraine', ' the', ' Kazakhstan', ' Georgia']
# Niagara Falls, target: Canada   ==>   predicted: [' Russia', ' the', ' Georgia', ' Ukraine', ' Belarus']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Russia', ' the', ' Ukraine', ' Belarus', ' Bor']
# Kyoto University, target: Japan   ==>   predicted: [' Russia', ' the', ' Georgia', ' Kazakhstan', ' Uzbek']
# Hattfjelldal, target: Norway   ==>   predicted: [' Russia', ' the', ' Ukraine', ' Belarus', ' Siberia']
# Ginza, target: Japan   ==>   predicted: [' Russia', ' the', ' Ukraine', ' Georgia', ' Belarus']
# Sydney Hospital, target: Australia   ==>   predicted: [' Russia', ' Georgia', ' the', ' Ukraine', ' Kazakhstan']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Russia', ' the', ' Georgia', ' Kazakhstan', ' Belarus']
# Higashikagawa, target: Japan   ==>   predicted: [' Russia', ' the', ' Georgia', ' Kazakhstan', ' Ukraine']
# Trento, target: Italy   ==>   predicted: [' Russia', ' the', ' Georgia', ' Ukraine', ' Belarus']
# Taj Mahal, target: India   ==>   predicted: [' Russia', ' the', ' Georgia', ' Ukraine', ' Uzbek']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Eibenstock, r = {} is located in the country of [P17], o = Germany)
# {'Jh_norm': tensor(147.0164, device='cuda:0'), 'bias_norm': 465.5903625488281, 'h_info': {'h_index': 3, 'token_id': 13578, 'token': 'stock'}, 'consider_residual': (True, 3, tensor(39.9263, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' South', ' Germany', ' Austria', ' Afghanistan', ' the']
# Niagara Falls, target: Canada   ==>   predicted: [' South', ' the', ' Georgia', ' Canada', ' Ireland']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Norway', ' Austria', ' South', ' the', ' Denmark']
# Kyoto University, target: Japan   ==>   predicted: [' the', ' Japan', ' Georgia', ' South', ' Austria']
# Hattfjelldal, target: Norway   ==>   predicted: [' Germany', ' the', ' Nam', ' Austria', ' Sweden']
# Ginza, target: Japan   ==>   predicted: [' South', ' the', ' Germany', ' Japan', ' Austria']
# Sydney Hospital, target: Australia   ==>   predicted: [' Georgia', ' South', ' the', ' Japan', ' Israel']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' South', ' the', ' India', ' Georgia', ' Norway']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' the', ' South', ' Georgia', ' Germany']
# Trento, target: Italy   ==>   predicted: [' South', ' the', ' Georgia', ' Austria', ' Albania']
# Taj Mahal, target: India   ==>   predicted: [' Austria', ' the', ' South', ' Georgia', ' Bh']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Kyoto University, r = {} is located in the country of [P17], o = Japan)
# {'Jh_norm': tensor(178.0295, device='cuda:0'), 'bias_norm': 364.0380859375, 'h_info': {'h_index': 2, 'token_id': 2059, 'token': ' University'}, 'consider_residual': (True, 3, tensor(39.8634, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Japan', ' South', ' Japanese', ' India', ' Kyoto']
# Niagara Falls, target: Canada   ==>   predicted: [' Japan', ' the', ' India', ' South', ' modern']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Japan', ' Kyoto', ' the', ' Sh', ' J']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Kyoto', ' Fuk', ' Japanese', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Japan', ' Kyoto', ' the', ' Sh', ' which']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Kyoto', ' Japanese', ' Sh', ' Okinawa']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' the', ' Kyoto', ' South', ' Okinawa']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' India', ' the', ' ancient', ' Kyoto']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Kyoto', ' Japanese', ' Sh', ' Kan']
# Trento, target: Italy   ==>   predicted: [' Japan', ' Kyoto', ' the', ' Sh', ' which']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' Kyoto', ' the', ' Sh', ' India']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = HSBC Bank Malta, r = {} is located in the country of [P17], o = Malta)
# {'Jh_norm': tensor(189.5621, device='cuda:0'), 'bias_norm': 353.5240783691406, 'h_info': {'h_index': 3, 'token_id': 35206, 'token': ' Malta'}, 'consider_residual': (True, 3, tensor(44.0196, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Malta', ' the', ' Cyprus', ' Gibraltar', ' Saint']
# Niagara Falls, target: Canada   ==>   predicted: [' Malta', ' the', ' Cyprus', ' Saint', ' Great']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Malta', ' the', ' Luxembourg', ' Cyprus', ' Gibraltar']
# Kyoto University, target: Japan   ==>   predicted: [' Malta', ' the', ' Kos', ' Cyprus', ' Saint']
# Hattfjelldal, target: Norway   ==>   predicted: [' Malta', ' the', ' Gibraltar', ' Cyprus', ' Lie']
# Ginza, target: Japan   ==>   predicted: [' Malta', ' the', ' Gibraltar', ' Luxembourg', ' Cyprus']
# Sydney Hospital, target: Australia   ==>   predicted: [' the', ' Malta', ' Monaco', ' Cyprus', ' Saint']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Malta', ' Gibraltar', ' the', ' Great', ' Saint']
# Higashikagawa, target: Japan   ==>   predicted: [' Malta', ' the', ' Gibraltar', ' Cyprus', ' Kos']
# Trento, target: Italy   ==>   predicted: [' Malta', ' the', ' Kos', ' Cyprus', ' Mold']
# Taj Mahal, target: India   ==>   predicted: [' Malta', ' the', ' Cyprus', ' Great', ' Saint']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Kfar Giladi, r = {} is located in the country of [P17], o = Israel)
# {'Jh_norm': tensor(152.9612, device='cuda:0'), 'bias_norm': 407.92779541015625, 'h_info': {'h_index': 3, 'token_id': 9189, 'token': 'adi'}, 'consider_residual': (True, 3, tensor(40.3523, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Jordan', ' Israel', ' Georgia', ' Palestine', ' Syria']
# Niagara Falls, target: Canada   ==>   predicted: [' Israel', ' Palestine', ' Georgia', ' Jordan', ' the']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Israel', ' Jordan', ' Georgia', ' the', ' Azerbaijan']
# Kyoto University, target: Japan   ==>   predicted: [' Georgia', ' Jordan', ' Israel', ' the', ' Azerbaijan']
# Hattfjelldal, target: Norway   ==>   predicted: [' Israel', ' the', ' Palestine', ' Georgia', ' Jordan']
# Ginza, target: Japan   ==>   predicted: [' Jordan', ' Israel', ' Palestine', ' the', ' Qatar']
# Sydney Hospital, target: Australia   ==>   predicted: [' Jordan', ' Georgia', ' Palestine', ' Israel', ' the']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Georgia', ' Azerbaijan', ' Iran', ' Iraq', ' the']
# Higashikagawa, target: Japan   ==>   predicted: [' Georgia', ' Israel', ' Jordan', ' the', ' Cyprus']
# Trento, target: Italy   ==>   predicted: [' Jordan', ' Palestine', ' Israel', ' Georgia', ' the']
# Taj Mahal, target: India   ==>   predicted: [' Jordan', ' Israel', ' Palestine', ' the', ' Georgia']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Hultsfred Municipality, r = {} is located in the country of [P17], o = Sweden)
# {'Jh_norm': tensor(159.6166, device='cuda:0'), 'bias_norm': 451.8418884277344, 'h_info': {'h_index': 4, 'token_id': 1483, 'token': 'ality'}, 'consider_residual': (True, 3, tensor(39.8901, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Sweden', ' Norway', ' H', ' the', ' Iceland']
# Niagara Falls, target: Canada   ==>   predicted: [' Sweden', ' the', ' H', ' Norway', ' Iceland']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Sweden', ' Norway', ' the', ' Denmark', ' H']
# Kyoto University, target: Japan   ==>   predicted: [' the', ' Sweden', ' S', ' H', ' J']
# Hattfjelldal, target: Norway   ==>   predicted: [' Sweden', ' H', ' the', ' S', ' Norway']
# Ginza, target: Japan   ==>   predicted: [' the', ' Sweden', ' Norway', ' H', ' South']
# Sydney Hospital, target: Australia   ==>   predicted: [' the', ' Sweden', ' Sw', ' S', ' H']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' the', ' Norway', ' Sweden', ' H', ' Iceland']
# Higashikagawa, target: Japan   ==>   predicted: [' H', ' the', ' S', ' Sweden', ' J']
# Trento, target: Italy   ==>   predicted: [' Sweden', ' the', ' S', ' Norway', ' H']
# Taj Mahal, target: India   ==>   predicted: [' the', ' Sweden', ' H', ' S', ' Iceland']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Hattfjelldal, r = {} is located in the country of [P17], o = Norway)
# {'Jh_norm': tensor(154.4795, device='cuda:0'), 'bias_norm': 448.0718688964844, 'h_info': {'h_index': 5, 'token_id': 31748, 'token': 'dal'}, 'consider_residual': (True, 3, tensor(40.1022, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Norway', ' Iceland', ' Denmark', ' South', ' Sweden']
# Niagara Falls, target: Canada   ==>   predicted: [' Norway', ' Iceland', ' Denmark', ' Sweden', ' Zealand']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Norway', ' Denmark', ' Iceland', ' Sweden', ' Finland']
# Kyoto University, target: Japan   ==>   predicted: [' Iceland', ' Denmark', ' Norway', ' Finland', ' Sweden']
# Hattfjelldal, target: Norway   ==>   predicted: [' Norway', ' Iceland', ' Denmark', ' Sweden', ' Finland']
# Ginza, target: Japan   ==>   predicted: [' Norway', ' Denmark', ' Iceland', ' South', ' Finland']
# Sydney Hospital, target: Australia   ==>   predicted: [' Norway', ' Denmark', ' Iceland', ' South', ' Sweden']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Norway', ' Iceland', ' Denmark', ' South', ' Finland']
# Higashikagawa, target: Japan   ==>   predicted: [' Norway', ' Denmark', ' Iceland', ' J', ' Sweden']
# Trento, target: Italy   ==>   predicted: [' Norway', ' Denmark', ' Iceland', ' Sweden', ' South']
# Taj Mahal, target: India   ==>   predicted: [' Iceland', ' Norway', ' Denmark', ' Sweden', ' South']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Russian-Armenian University, r = {} is located in the country of [P17], o = Armenia)
# {'Jh_norm': tensor(175.3202, device='cuda:0'), 'bias_norm': 435.499267578125, 'h_info': {'h_index': 5, 'token_id': 2059, 'token': ' University'}, 'consider_residual': (True, 3, tensor(39.7093, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Georgia', ' Armenia', ' Russia', ' the', ' Turkey']
# Niagara Falls, target: Canada   ==>   predicted: [' Armenia', ' Georgia', ' the', ' Republic', ' Azerbaijan']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Armenia', ' Georgia', ' the', ' Azerbaijan', ' Russia']
# Kyoto University, target: Japan   ==>   predicted: [' Georgia', ' Armenia', ' the', ' Azerbaijan', ' Nag']
# Hattfjelldal, target: Norway   ==>   predicted: [' Armenia', ' Georgia', ' the', ' Russia', ' Azerbaijan']
# Ginza, target: Japan   ==>   predicted: [' Georgia', ' Armenia', ' Azerbaijan', ' the', ' Turkey']
# Sydney Hospital, target: Australia   ==>   predicted: [' Georgia', ' Armenia', ' the', ' Azerbaijan', ' Russia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Georgia', ' Armenia', ' the', ' Azerbaijan', ' Russia']
# Higashikagawa, target: Japan   ==>   predicted: [' Georgia', ' Armenia', ' Nag', ' the', ' Kar']
# Trento, target: Italy   ==>   predicted: [' Georgia', ' Armenia', ' Azerbaijan', ' the', ' Russia']
# Taj Mahal, target: India   ==>   predicted: [' Armenia', ' Georgia', ' the', ' Turkey', ' Russia']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Pontecorvo, r = {} is located in the country of [P17], o = Italy)
# {'Jh_norm': tensor(137.4398, device='cuda:0'), 'bias_norm': 461.53399658203125, 'h_info': {'h_index': 3, 'token_id': 13038, 'token': 'vo'}, 'consider_residual': (True, 3, tensor(40.4515, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' South', ' Chile', ' Spain', ' Portugal', ' Georgia']
# Niagara Falls, target: Canada   ==>   predicted: [' Portugal', ' South', ' Brazil', ' Chile', ' the']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Georgia', ' South', ' Portugal', ' the', ' Brazil']
# Kyoto University, target: Japan   ==>   predicted: [' Georgia', ' Brazil', ' Japan', ' the', ' Italy']
# Hattfjelldal, target: Norway   ==>   predicted: [' the', ' Brazil', ' South', ' Georgia', ' Portugal']
# Ginza, target: Japan   ==>   predicted: [' Italy', ' South', ' Japan', ' Brazil', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' Georgia', ' Brazil', ' South', ' the', ' Portugal']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Georgia', ' South', ' the', ' Brazil', ' Portugal']
# Higashikagawa, target: Japan   ==>   predicted: [' Georgia', ' Japan', ' the', ' T', ' South']
# Trento, target: Italy   ==>   predicted: [' Italy', ' Portugal', ' Georgia', ' Brazil', ' the']
# Taj Mahal, target: India   ==>   predicted: [' Italy', ' the', ' T', ' Malta', ' Georgia']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Astrid Lindgren Memorial Award, r = {} is located in the country of [P17], o = Sweden)
# {'Jh_norm': tensor(175.1065, device='cuda:0'), 'bias_norm': 508.93829345703125, 'h_info': {'h_index': 6, 'token_id': 11289, 'token': ' Award'}, 'consider_residual': (True, 3, tensor(39.7594, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Sweden', ' Norway', ' Iceland', ' Denmark', ' Finland']
# Niagara Falls, target: Canada   ==>   predicted: [' Sweden', ' Norway', ' Iceland', ' Finland', ' Denmark']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Sweden', ' Norway', ' Iceland', ' Denmark', ' Finland']
# Kyoto University, target: Japan   ==>   predicted: [' Sweden', ' Iceland', ' Norway', ' Finland', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Sweden', ' Norway', ' Iceland', ' Denmark', ' Finland']
# Ginza, target: Japan   ==>   predicted: [' Sweden', ' Norway', ' Iceland', ' Finland', ' Denmark']
# Sydney Hospital, target: Australia   ==>   predicted: [' Sweden', ' Norway', ' Iceland', ' the', ' Denmark']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Norway', ' Sweden', ' Iceland', ' the', ' Finland']
# Higashikagawa, target: Japan   ==>   predicted: [' Sweden', ' Norway', ' Iceland', ' S', ' the']
# Trento, target: Italy   ==>   predicted: [' Sweden', ' Norway', ' Iceland', ' Denmark', ' the']
# Taj Mahal, target: India   ==>   predicted: [' Sweden', ' Iceland', ' Norway', ' the', ' Denmark']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Turkey national rugby union team, r = {} is located in the country of [P17], o = Turkey)
# {'Jh_norm': tensor(168.4832, device='cuda:0'), 'bias_norm': 457.7756652832031, 'h_info': {'h_index': 4, 'token_id': 1074, 'token': ' team'}, 'consider_residual': (True, 3, tensor(39.7720, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Turkey', ' Georgia', ' the', ' Kazakhstan', ' Turk']
# Niagara Falls, target: Canada   ==>   predicted: [' Turkey', ' Georgia', ' the', ' Turk', ' Croatia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Turkey', ' Turk', ' the', ' Georgia', ' Macedonia']
# Kyoto University, target: Japan   ==>   predicted: [' Georgia', ' Turkey', ' the', ' Azerbaijan', ' Kazakhstan']
# Hattfjelldal, target: Norway   ==>   predicted: [' the', ' Turkey', ' Turk', ' Georgia', ' Bosnia']
# Ginza, target: Japan   ==>   predicted: [' Turkey', ' Turk', ' the', ' Georgia', ' Azerbaijan']
# Sydney Hospital, target: Australia   ==>   predicted: [' Georgia', ' Turkey', ' the', ' Turk', ' Azerbaijan']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Georgia', ' Turkey', ' the', ' Azerbaijan', ' Kazakhstan']
# Higashikagawa, target: Japan   ==>   predicted: [' Turk', ' Turkey', ' Georgia', ' the', ' Sar']
# Trento, target: Italy   ==>   predicted: [' Georgia', ' Turkey', ' Monteneg', ' Azerbaijan', ' Turk']
# Taj Mahal, target: India   ==>   predicted: [' Turk', ' Turkey', ' the', ' Georgia', ' Bosnia']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Nova Friburgo, r = {} is located in the country of [P17], o = Brazil)
# {'Jh_norm': tensor(145.0072, device='cuda:0'), 'bias_norm': 470.93304443359375, 'h_info': {'h_index': 5, 'token_id': 2188, 'token': 'go'}, 'consider_residual': (True, 3, tensor(40.1988, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' South', ' Portugal', ' Brazil', ' Spain', ' Chile']
# Niagara Falls, target: Canada   ==>   predicted: [' Portugal', ' South', ' Croatia', ' Brazil', ' Nova']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Sweden', ' Croatia', ' Macedonia', ' Iceland', ' Monteneg']
# Kyoto University, target: Japan   ==>   predicted: [' Brazil', ' Georgia', ' the', ' South', ' Portugal']
# Hattfjelldal, target: Norway   ==>   predicted: [' Sweden', ' Slovenia', ' Iceland', ' Lie', ' Finland']
# Ginza, target: Japan   ==>   predicted: [' South', ' Cur', ' Brazil', ' Portugal', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' Georgia', ' South', ' Croatia', ' the', ' Brazil']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' South', ' the', ' Georgia', ' Brazil', ' Portugal']
# Higashikagawa, target: Japan   ==>   predicted: [' Georgia', ' T', ' the', ' South', ' Croatia']
# Trento, target: Italy   ==>   predicted: [' Portugal', ' Monteneg', ' South', ' Brazil', ' Georgia']
# Taj Mahal, target: India   ==>   predicted: [' Croatia', ' South', ' Georgia', ' Albania', ' Malta']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Sydney Peace Prize, r = {} is located in the country of [P17], o = Australia)
# {'Jh_norm': tensor(179.8965, device='cuda:0'), 'bias_norm': 419.0908508300781, 'h_info': {'h_index': 4, 'token_id': 15895, 'token': ' Prize'}, 'consider_residual': (True, 3, tensor(39.7147, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Australia', ' the', ' South', ' Afghanistan', ' Japan']
# Niagara Falls, target: Canada   ==>   predicted: [' Australia', ' the', ' Papua', ' Samoa', ' NSW']
# Valdemarsvik, target: Sweden   ==>   predicted: [' the', ' Papua', ' Australia', ' New', ' your']
# Kyoto University, target: Japan   ==>   predicted: [' the', ' Japan', ' Australia', ' Sri', ' origin']
# Hattfjelldal, target: Norway   ==>   predicted: [' the', ' New', ' Papua', ' origin', ' Australia']
# Ginza, target: Japan   ==>   predicted: [' the', ' Japan', ' Australia', ' New', ' South']
# Sydney Hospital, target: Australia   ==>   predicted: [' Australia', ' the', ' Georgia', ' Papua', ' NSW']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Australia', ' the', ' Sri', ' India', ' New']
# Higashikagawa, target: Japan   ==>   predicted: [' the', ' Papua', ' Japan', ' New', ' Australia']
# Trento, target: Italy   ==>   predicted: [' the', ' Australia', ' Papua', ' Georgia', ' New']
# Taj Mahal, target: India   ==>   predicted: [' the', ' Australia', ' Sri', ' New', ' Sydney']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Christian Medical College Ludhiana, r = {} is located in the country of [P17], o = India)
# {'Jh_norm': tensor(147.1245, device='cuda:0'), 'bias_norm': 363.8514404296875, 'h_info': {'h_index': 5, 'token_id': 7484, 'token': 'iana'}, 'consider_residual': (True, 3, tensor(41.6481, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' India', ' West', ' Punjab', ' Gujarat', ' Go']
# Niagara Falls, target: Canada   ==>   predicted: [' India', ' Punjab', ' Gujarat', ' Lad', ' West']
# Valdemarsvik, target: Sweden   ==>   predicted: [' India', ' Lud', ' Gujarat', ' And', ' Punjab']
# Kyoto University, target: Japan   ==>   predicted: [' India', ' Pakistan', ' Punjab', ' J', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' India', ' Lud', ' the', ' Pakistan', ' Punjab']
# Ginza, target: Japan   ==>   predicted: [' India', ' Gujarat', ' Pakistan', ' South', ' Punjab']
# Sydney Hospital, target: Australia   ==>   predicted: [' India', ' Lud', ' Sri', ' Go', ' Sw']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' India', ' Punjab', ' Lad', ' Gujarat', ' Pakistan']
# Higashikagawa, target: Japan   ==>   predicted: [' India', ' Gujarat', ' J', ' Lud', ' Nepal']
# Trento, target: Italy   ==>   predicted: [' India', ' Mald', ' Lud', ' West', ' Maurit']
# Taj Mahal, target: India   ==>   predicted: [' India', ' Punjab', ' Gujarat', ' Lud', ' Pakistan']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Yokohama International School, r = {} is located in the country of [P17], o = Japan)
# {'Jh_norm': tensor(169.5027, device='cuda:0'), 'bias_norm': 413.2548828125, 'h_info': {'h_index': 5, 'token_id': 3961, 'token': ' School'}, 'consider_residual': (True, 3, tensor(39.7535, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Japan', ' Korea', ' China', ' Okinawa', ' South']
# Niagara Falls, target: Canada   ==>   predicted: [' Japan', ' Hok', ' South', ' Korea', ' the']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' the', ' Yok']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Fuk', ' Okinawa', ' Hok', ' China']
# Hattfjelldal, target: Norway   ==>   predicted: [' Japan', ' the', ' Okinawa', ' Se', ' Yok']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Okinawa', ' Yok', ' Korea', ' Osaka']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' Korea', ' Okinawa', ' the', ' South']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' Thailand', ' China', ' the', ' Korea']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Okinawa', ' Fuk', ' Japanese', ' Hok']
# Trento, target: Italy   ==>   predicted: [' Japan', ' Okinawa', ' the', ' South', ' Korea']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' Okinawa', ' the', ' China', ' Korea']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Ateneo de Madrid, r = {} is located in the country of [P17], o = Spain)
# {'Jh_norm': tensor(163.1783, device='cuda:0'), 'bias_norm': 371.5808410644531, 'h_info': {'h_index': 5, 'token_id': 14708, 'token': ' Madrid'}, 'consider_residual': (True, 3, tensor(42.0896, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Spain', ' And', ' the', ' Mal', ' China']
# Niagara Falls, target: Canada   ==>   predicted: [' the', ' Spain', ' Ar', ' Se', ' And']
# Valdemarsvik, target: Sweden   ==>   predicted: [' the', ' Se', ' Mal', ' Spain', ' Ar']
# Kyoto University, target: Japan   ==>   predicted: [' the', ' Spain', ' Se', ' China', ' T']
# Hattfjelldal, target: Norway   ==>   predicted: [' Se', ' the', ' Ar', ' Mal', ' Spain']
# Ginza, target: Japan   ==>   predicted: [' Spain', ' And', ' the', ' Mal', ' Se']
# Sydney Hospital, target: Australia   ==>   predicted: [' the', ' Mal', ' Malaysia', ' Se', ' Philippines']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' the', ' T', ' Spain', ' China', ' Malaysia']
# Higashikagawa, target: Japan   ==>   predicted: [' Se', ' the', ' Mal', ' T', ' Ar']
# Trento, target: Italy   ==>   predicted: [' Spain', ' the', ' And', ' Se', ' Ar']
# Taj Mahal, target: India   ==>   predicted: [' the', ' Spain', ' And', ' Mal', ' Ar']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Toronto Police Service, r = {} is located in the country of [P17], o = Canada)
# {'Jh_norm': tensor(159.6335, device='cuda:0'), 'bias_norm': 359.4815368652344, 'h_info': {'h_index': 2, 'token_id': 4809, 'token': ' Service'}, 'consider_residual': (True, 3, tensor(39.9874, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Turkey', ' Japan', ' Mexico', ' Spain', ' Israel']
# Niagara Falls, target: Canada   ==>   predicted: [' Ontario', ' Jamaica', ' Newfoundland', ' Canada', ' Turkey']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Trinidad', ' Iceland', ' Newfoundland', ' Turkey', ' Gu']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Turkey', ' Georgia', ' China', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' the', ' Iceland', ' Turkey', ' Israel', ' Germany']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Turkey', ' Italy', ' Trinidad', ' Jamaica']
# Sydney Hospital, target: Australia   ==>   predicted: [' Trinidad', ' Turkey', ' Georgia', ' the', ' Jamaica']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Great', ' India', ' Turkey', ' Sri', ' the']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Turkey', ' Jamaica', ' the', ' Trinidad']
# Trento, target: Italy   ==>   predicted: [' Gu', ' Turkey', ' Monteneg', ' Italy', ' Trinidad']
# Taj Mahal, target: India   ==>   predicted: [' Great', ' Turkey', ' Jamaica', ' Trinidad', ' Kuwait']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Ginza, r = {} is located in the country of [P17], o = Japan)
# {'Jh_norm': tensor(150.3493, device='cuda:0'), 'bias_norm': 421.547607421875, 'h_info': {'h_index': 2, 'token_id': 4496, 'token': 'za'}, 'consider_residual': (True, 3, tensor(42.1583, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Japan', ' China', ' Korea', ' South', ' Taiwan']
# Niagara Falls, target: Canada   ==>   predicted: [' Japan', ' Hok', ' Ni', ' the', ' Gin']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Japan', ' the', ' S', ' Hok', ' J']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Fuk', ' Ky', ' Hok', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Japan', ' the', ' J', ' O', ' G']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Tokyo', ' Gin', ' the', ' Sh']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' the', ' Georgia', ' Israel', ' Germany']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' Sh', ' the', ' China', ' Ky']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Nag', ' Hig', ' Hok', ' Sh']
# Trento, target: Italy   ==>   predicted: [' Japan', ' the', ' Georgia', ' Ch', ' Kir']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' the', ' Sh', ' Ch', ' J']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Hellenic Police, r = {} is located in the country of [P17], o = Greece)
# {'Jh_norm': tensor(168.6098, device='cuda:0'), 'bias_norm': 421.39825439453125, 'h_info': {'h_index': 2, 'token_id': 4287, 'token': ' Police'}, 'consider_residual': (True, 3, tensor(39.8329, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Greece', ' Turkey', ' Macedonia', ' Cyprus', ' the']
# Niagara Falls, target: Canada   ==>   predicted: [' Greece', ' the', ' Turkey', ' Cyprus', ' Macedonia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Greece', ' Macedonia', ' the', ' Turkey', ' Cyprus']
# Kyoto University, target: Japan   ==>   predicted: [' Greece', ' the', ' Turkey', ' Kos', ' Cyprus']
# Hattfjelldal, target: Norway   ==>   predicted: [' Greece', ' the', ' Cre', ' Turkey', ' Macedonia']
# Ginza, target: Japan   ==>   predicted: [' Greece', ' Turkey', ' the', ' Macedonia', ' Cyprus']
# Sydney Hospital, target: Australia   ==>   predicted: [' Greece', ' the', ' Turkey', ' Cyprus', ' Macedonia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Greece', ' the', ' Turkey', ' Ae', ' Hell']
# Higashikagawa, target: Japan   ==>   predicted: [' Greece', ' Cre', ' Kos', ' the', ' Turkey']
# Trento, target: Italy   ==>   predicted: [' Greece', ' Macedonia', ' Turkey', ' the', ' Cyprus']
# Taj Mahal, target: India   ==>   predicted: [' Greece', ' Turkey', ' Cyprus', ' the', ' Macedonia']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Kamikita District, r = {} is located in the country of [P17], o = Japan)
# {'Jh_norm': tensor(168.7699, device='cuda:0'), 'bias_norm': 474.6268615722656, 'h_info': {'h_index': 4, 'token_id': 5665, 'token': ' District'}, 'consider_residual': (True, 3, tensor(39.8053, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Japan', ' J', ' O', ' Kam', ' Okinawa']
# Niagara Falls, target: Canada   ==>   predicted: [' Japan', ' the', ' O', ' J', ' Ryu']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Japan', ' Kam', ' the', ' J', ' O']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Fuk', ' the', ' Okinawa', ' Kam']
# Hattfjelldal, target: Norway   ==>   predicted: [' Japan', ' the', ' O', ' J', ' Kam']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Okinawa', ' Fuk', ' the', ' Ryu']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' the', ' O', ' Kam', ' Okinawa']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' the', ' O', ' Sh', ' J']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Ryu', ' Kam', ' Fuk', ' Okinawa']
# Trento, target: Italy   ==>   predicted: [' Japan', ' the', ' J', ' Kam', ' Sh']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' the', ' Kam', ' J', ' Sh']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Inami, Toyama, r = {} is located in the country of [P17], o = Japan)
# {'Jh_norm': tensor(155.7064, device='cuda:0'), 'bias_norm': 477.0914611816406, 'h_info': {'h_index': 4, 'token_id': 1689, 'token': 'ama'}, 'consider_residual': (True, 3, tensor(40.6118, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Japan', ' H', ' Korea', ' O', ' South']
# Niagara Falls, target: Canada   ==>   predicted: [' Ni', ' A', ' Japan', ' H', ' O']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Hok', ' Japan', ' A', ' Ni', ' H']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Fuk', ' Ky', ' Hok', ' Ni']
# Hattfjelldal, target: Norway   ==>   predicted: [' H', ' Japan', ' the', ' A', ' K']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Fuk', ' Osaka', ' Ni', ' I']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' O', ' Ni', ' A', ' I']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' A', ' O', ' Sh', ' I']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Fuk', ' Ni', ' H', ' J']
# Trento, target: Italy   ==>   predicted: [' A', ' Ch', ' Japan', ' H', ' the']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' Ni', ' H', ' I', ' Sh']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Thuringian Highland, r = {} is located in the country of [P17], o = Germany)
# {'Jh_norm': tensor(175.2178, device='cuda:0'), 'bias_norm': 462.66033935546875, 'h_info': {'h_index': 3, 'token_id': 39874, 'token': ' Highland'}, 'consider_residual': (True, 3, tensor(39.8433, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Germany', ' H', ' Austria', ' the', ' South']
# Niagara Falls, target: Canada   ==>   predicted: [' Germany', ' the', ' H', ' Austria', ' Switzerland']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Germany', ' the', ' H', ' Austria', ' Th']
# Kyoto University, target: Japan   ==>   predicted: [' Germany', ' the', ' Austria', ' H', ' Switzerland']
# Hattfjelldal, target: Norway   ==>   predicted: [' Germany', ' H', ' the', ' Th', ' Lower']
# Ginza, target: Japan   ==>   predicted: [' Germany', ' the', ' Switzerland', ' Austria', ' H']
# Sydney Hospital, target: Australia   ==>   predicted: [' Germany', ' the', ' Austria', ' Switzerland', ' Sch']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' the', ' Germany', ' Th', ' H', ' Austria']
# Higashikagawa, target: Japan   ==>   predicted: [' Germany', ' H', ' the', ' Th', ' Lower']
# Trento, target: Italy   ==>   predicted: [' the', ' Germany', ' H', ' Lower', ' Austria']
# Taj Mahal, target: India   ==>   predicted: [' Germany', ' Austria', ' the', ' H', ' Th']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ...
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' France', ' the', ' North', ' Morocco', ' Islam']
# Niagara Falls, target: Canada   ==>   predicted: [' the', ' France', ' North', ' Muslim', ' Islam']
# Valdemarsvik, target: Sweden   ==>   predicted: [' the', ' France', ' Islam', ' North', ' Morocco']
# Kyoto University, target: Japan   ==>   predicted: [' the', ' France', ' Islam', ' Muslim', ' Turkey']
# Hattfjelldal, target: Norway   ==>   predicted: [' the', ' Islam', ' France', ' North', ' Morocco']
# Ginza, target: Japan   ==>   predicted: [' France', ' the', ' Islam', ' North', ' Muslim']
# Sydney Hospital, target: Australia   ==>   predicted: [' the', ' France', ' Islam', ' North', ' Turkey']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' the', ' France', ' Islam', ' Pakistan', ' North']
# Higashikagawa, target: Japan   ==>   predicted: [' the', ' Islam', ' France', ' Muslim', ' North']
# Trento, target: Italy   ==>   predicted: [' the', ' France', ' Islam', ' Morocco', ' North']
# Taj Mahal, target: India   ==>   predicted: [' the', ' France', ' Islam', ' Morocco', ' Muslim']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Llanquihue Province, r = {} is located in the country of [P17], o = Chile)
# {'Jh_norm': tensor(154.0401, device='cuda:0'), 'bias_norm': 416.11199951171875, 'h_info': {'h_index': 5, 'token_id': 22783, 'token': ' Province'}, 'consider_residual': (True, 3, tensor(39.8778, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Chile', ' Honduras', ' Mexico', ' Costa', ' New']
# Niagara Falls, target: Canada   ==>   predicted: [' Chile', ' Costa', ' New', ' Samoa', ' Honduras']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Chile', ' New', ' the', ' Ant', ' Mic']
# Kyoto University, target: Japan   ==>   predicted: [' Chile', ' Brazil', ' the', ' Costa', ' Ant']
# Hattfjelldal, target: Norway   ==>   predicted: [' New', ' the', ' Ant', ' Mic', ' Chile']
# Ginza, target: Japan   ==>   predicted: [' Chile', ' New', ' Costa', ' the', ' Brazil']
# Sydney Hospital, target: Australia   ==>   predicted: [' Chile', ' Costa', ' the', ' New', ' Columbia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Chile', ' the', ' New', ' Bolivia', ' Peru']
# Higashikagawa, target: Japan   ==>   predicted: [' Chile', ' New', ' the', ' Honduras', ' Nicaragua']
# Trento, target: Italy   ==>   predicted: [' Chile', ' Ecuador', ' Costa', ' Peru', ' New']
# Taj Mahal, target: India   ==>   predicted: [' Chile', ' Ant', ' New', ' Guatemala', ' Honduras']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Yamato Museum, r = {} is located in the country of [P17], o = Japan)
# {'Jh_norm': tensor(185.0650, device='cuda:0'), 'bias_norm': 455.53375244140625, 'h_info': {'h_index': 3, 'token_id': 9594, 'token': ' Museum'}, 'consider_residual': (True, 3, tensor(39.7217, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Japan', ' Okinawa', ' Yam', ' the', ' Ky']
# Niagara Falls, target: Canada   ==>   predicted: [' Japan', ' the', ' Nag', ' Kir', ' Kan']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Japan', ' the', ' Nag', ' Yam', ' Okinawa']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Fuk', ' Yam', ' Okinawa', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Japan', ' the', ' Kur', ' Yam', ' Nam']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Yam', ' Okinawa', ' Osaka', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' the', ' Yam', ' Okinawa', ' Georgia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' the', ' Thailand', ' Sh', ' Yam']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Yam', ' Okinawa', ' Nag', ' Kan']
# Trento, target: Italy   ==>   predicted: [' Japan', ' the', ' Okinawa', ' Kir', ' Yam']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' the', ' Okinawa', ' Sh', ' Taj']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Valea lui Mihai, r = {} is located in the country of [P17], o = Romania)
# {'Jh_norm': tensor(147.5018, device='cuda:0'), 'bias_norm': 446.11053466796875, 'h_info': {'h_index': 7, 'token_id': 1872, 'token': 'ai'}, 'consider_residual': (True, 3, tensor(42.6654, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Georgia', ' Romania', ' China', ' Macedonia', ' Hungary']
# Niagara Falls, target: Canada   ==>   predicted: [' Romania', ' Mold', ' Croatia', ' Georgia', ' Macedonia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Georgia', ' Belarus', ' Mold', ' Macedonia', ' Romania']
# Kyoto University, target: Japan   ==>   predicted: [' Georgia', ' Cambodia', ' Romania', ' China', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Mold', ' Romania', ' Georgia', ' Macedonia', ' Hungary']
# Ginza, target: Japan   ==>   predicted: [' Romania', ' Georgia', ' Mold', ' China', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' Romania', ' Georgia', ' Cambodia', ' Madagascar', ' Rhodes']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Georgia', ' Kazakhstan', ' Laos', ' Mongolia', ' China']
# Higashikagawa, target: Japan   ==>   predicted: [' Romania', ' Georgia', ' China', ' Cyprus', ' the']
# Trento, target: Italy   ==>   predicted: [' Romania', ' Mold', ' Cors', ' Albania', ' Macedonia']
# Taj Mahal, target: India   ==>   predicted: [' Romania', ' Georgia', ' Mold', ' Hungary', ' Albania']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Central Black Forest, r = {} is located in the country of [P17], o = Germany)
# {'Jh_norm': tensor(165.6792, device='cuda:0'), 'bias_norm': 441.57232666015625, 'h_info': {'h_index': 2, 'token_id': 9115, 'token': ' Forest'}, 'consider_residual': (True, 3, tensor(44.7868, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Belarus', ' Russia', ' Ukraine', ' Hungary', ' Poland']
# Niagara Falls, target: Canada   ==>   predicted: [' Germany', ' Belgium', ' France', ' Luxembourg', ' Austria']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Belarus', ' Poland', ' Russia', ' Germany', ' Hungary']
# Kyoto University, target: Japan   ==>   predicted: [' Belarus', ' Hungary', ' Ukraine', ' Russia', ' Georgia']
# Hattfjelldal, target: Norway   ==>   predicted: [' Germany', ' Bav', ' Sax', ' Austria', ' Sw']
# Ginza, target: Japan   ==>   predicted: [' Germany', ' Austria', ' Bav', ' Hungary', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' Belgium', ' Germany', ' France', ' Switzerland', ' Luxembourg']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Belarus', ' Russia', ' Ukraine', ' Kazakhstan', ' Romania']
# Higashikagawa, target: Japan   ==>   predicted: [' Belarus', ' Hungary', ' Germany', ' Romania', ' Georgia']
# Trento, target: Italy   ==>   predicted: [' Belgium', ' Luxembourg', ' France', ' Luxem', ' Romania']
# Taj Mahal, target: India   ==>   predicted: [' Belgium', ' Luxembourg', ' Austria', ' Hungary', ' Romania']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Sahneh County, r = {} is located in the country of [P17], o = Iran)
# {'Jh_norm': tensor(167.5528, device='cuda:0'), 'bias_norm': 478.0169372558594, 'h_info': {'h_index': 3, 'token_id': 3418, 'token': ' County'}, 'consider_residual': (True, 3, tensor(40.0323, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Iran', ' Taj', ' Afghanistan', ' Iraq', ' Kurdistan']
# Niagara Falls, target: Canada   ==>   predicted: [' Iran', ' Taj', ' Iraq', ' Kurdistan', ' Turk']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Iran', ' Taj', ' Afghanistan', ' Turk', ' the']
# Kyoto University, target: Japan   ==>   predicted: [' Iran', ' Taj', ' Afghanistan', ' Iraq', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Iran', ' the', ' Kurdistan', ' Taj', ' Turk']
# Ginza, target: Japan   ==>   predicted: [' Iran', ' Taj', ' Iraq', ' Afghanistan', ' Turk']
# Sydney Hospital, target: Australia   ==>   predicted: [' Iran', ' Taj', ' Iraq', ' Afghanistan', ' Jordan']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Iran', ' Taj', ' Afghanistan', ' Iraq', ' the']
# Higashikagawa, target: Japan   ==>   predicted: [' Iran', ' Taj', ' Iraq', ' Turk', ' Afghanistan']
# Trento, target: Italy   ==>   predicted: [' Iran', ' Kurdistan', ' Taj', ' Iraq', ' Afghanistan']
# Taj Mahal, target: India   ==>   predicted: [' Iran', ' Taj', ' Turk', ' Afghanistan', ' Iraq']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Gmina Kleczew, r = {} is located in the country of [P17], o = Poland)
# {'Jh_norm': tensor(161.5484, device='cuda:0'), 'bias_norm': 489.601806640625, 'h_info': {'h_index': 5, 'token_id': 413, 'token': 'ew'}, 'consider_residual': (True, 3, tensor(40.3150, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Lithuania', ' Hungary']
# Niagara Falls, target: Canada   ==>   predicted: [' Poland', ' Croatia', ' Georgia', ' Sw', ' Lithuania']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Poland', ' Belarus', ' Lithuania', ' Hungary', ' Georgia']
# Kyoto University, target: Japan   ==>   predicted: [' Georgia', ' Poland', ' Belarus', ' Kazakhstan', ' Sw']
# Hattfjelldal, target: Norway   ==>   predicted: [' Poland', ' Hungary', ' Lithuania', ' the', ' Mold']
# Ginza, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' South']
# Sydney Hospital, target: Australia   ==>   predicted: [' Poland', ' Georgia', ' Sw', ' the', ' South']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Lithuania', ' India']
# Higashikagawa, target: Japan   ==>   predicted: [' Poland', ' Georgia', ' Hungary', ' Belarus', ' the']
# Trento, target: Italy   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Hungary', ' Lithuania']
# Taj Mahal, target: India   ==>   predicted: [' Poland', ' Hungary', ' Georgia', ' Belarus', ' Sw']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = University of Bern, r = {} is located in the country of [P17], o = Switzerland)
# {'Jh_norm': tensor(179.6087, device='cuda:0'), 'bias_norm': 364.681396484375, 'h_info': {'h_index': 2, 'token_id': 6206, 'token': ' Bern'}, 'consider_residual': (True, 3, tensor(44.4300, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Switzerland', ' neighboring', ' South', ' Great', ' Spain']
# Niagara Falls, target: Canada   ==>   predicted: [' Switzerland', ' Sw', ' Austria', ' Italy', ' the']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Switzerland', ' Lie', ' the', ' Sw', ' Great']
# Kyoto University, target: Japan   ==>   predicted: [' Switzerland', ' Italy', ' the', ' Sw', ' Spain']
# Hattfjelldal, target: Norway   ==>   predicted: [' Switzerland', ' the', ' Lie', ' Germany', ' Nam']
# Ginza, target: Japan   ==>   predicted: [' Switzerland', ' Sw', ' Italy', ' the', ' neighbouring']
# Sydney Hospital, target: Australia   ==>   predicted: [' Switzerland', ' Sw', ' the', ' Lie', ' South']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Switzerland', ' Italy', ' Austria', ' Ty', ' Great']
# Higashikagawa, target: Japan   ==>   predicted: [' Switzerland', ' neighboring', ' Bern', ' T', ' Italy']
# Trento, target: Italy   ==>   predicted: [' Switzerland', ' Italy', ' Spain', ' Lie', ' T']
# Taj Mahal, target: India   ==>   predicted: [' Switzerland', ' Austria', ' Great', ' Italy', ' Ty']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Tatsuno, r = {} is located in the country of [P17], o = Japan)
# {'Jh_norm': tensor(157.6741, device='cuda:0'), 'bias_norm': 519.6453247070312, 'h_info': {'h_index': 2, 'token_id': 36909, 'token': 'uno'}, 'consider_residual': (True, 3, tensor(40.1354, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Japan', ' South', ' Korea', ' China', ' France']
# Niagara Falls, target: Canada   ==>   predicted: [' Japan', ' South', ' Ni', ' A', ' the']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Japan', ' South', ' North', ' the', ' Norway']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Okinawa', ' the', ' South', ' Indonesia']
# Hattfjelldal, target: Norway   ==>   predicted: [' Japan', ' the', ' South', ' North', ' Sweden']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' South', ' Okinawa', ' Tokyo', ' Osaka']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' South', ' Georgia', ' the', ' North']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' South', ' the', ' Ni', ' Indonesia']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Okinawa', ' South', ' the', ' T']
# Trento, target: Italy   ==>   predicted: [' Japan', ' South', ' the', ' Georgia', ' North']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' South', ' the', ' Indonesia', ' T']
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Siemiatycze, r = {} is located in the country of [P17], o = Poland)
# {'Jh_norm': tensor(146.1310, device='cuda:0'), 'bias_norm': 424.5807800292969, 'h_info': {'h_index': 5, 'token_id': 2736, 'token': 'ze'}, 'consider_residual': (True, 3, tensor(42.0844, device='cuda:0'))}
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The Great Wall, target: China   ==>   predicted: [' Poland', ' Ukraine', ' Belarus', ' Bosnia', ' Georgia']
# Niagara Falls, target: Canada   ==>   predicted: [' Croatia', ' Bosnia', ' Poland', ' the', ' Hungary']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Poland', ' Belarus', ' Ukraine', ' the', ' Lithuania']
# Kyoto University, target: Japan   ==>   predicted: [' Georgia', ' Poland', ' the', ' Bosnia', ' Belarus']
# Hattfjelldal, target: Norway   ==>   predicted: [' Poland', ' the', ' Hungary', ' Bosnia', ' Mold']
# Ginza, target: Japan   ==>   predicted: [' Poland', ' the', ' Hungary', ' Belarus', ' C']
# Sydney Hospital, target: Australia   ==>   predicted: [' Georgia', ' Poland', ' the', ' Croatia', ' Mold']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Belarus', ' Georgia', ' Bosnia', ' Poland', ' the']
# Higashikagawa, target: Japan   ==>   predicted: [' Poland', ' the', ' Belarus', ' Hungary', ' Georgia']
# Trento, target: Italy   ==>   predicted: [' Poland', ' Georgia', ' Hungary', ' Bosnia', ' the']
# Taj Mahal, target: India   ==>   predicted: [' Poland', ' Gal', ' the', ' Hungary', ' Bosnia']

# %%
wh_norms = np.array([calc["misc"]['Jh_norm'] for calc in calculated_relations])
print(f"`Jh` contribution = {wh_norms.mean()} +/- {wh_norms.std()}") 

bias_norms = np.array([calc["misc"]['bias_norm'] for calc in calculated_relations])
print(f"`bias` contribution = {bias_norms.mean()} +/- {bias_norms.std()}")
# Out:
# `Jh` contribution = 17.88306264859393 +/- 10.812521437625106
# `bias` contribution = 449.51012426390685 +/- 50.287596469456304

# %%
calc["misc"]['bias_norm']
# Out:
# 424.5807800292969

# %%
wh_norms = np.array([calc["misc"]['Jh_norm'].item() for calc in calculated_relations])
print(f"`h + Jh` contribution = {wh_norms.mean()} +/- {wh_norms.std()}") 

bias_norms = np.array([calc["misc"]['bias_norm'] for calc in calculated_relations])
print(f"`bias` contribution = {bias_norms.mean()} +/- {bias_norms.std()}")
# Out:
# `h + Jh` contribution = 176.67704606594 +/- 211.29306737394754
# `bias` contribution = 451.78081724697483 +/- 204.08395684143662

# %%
calculated_relation_collections = []

for c in tqdm(correct_predict):
    relation_collection = estimate.estimate_relation_operator__for_all_subject_tokens(
        model, tokenizer,
        c["subject"],
        relation,
        layer=layer,
        device=model.device,
        consider_residual = True,
        approximate_rank = approximate_rank
    )

    calculated_relation_collections.append({
        "subject": c["subject"],
        "request": c,
        "all_weights_and_biases": [
            {
                "weight": calc.weight.cpu().numpy(),
                "bias": calc.bias.cpu().numpy(),
                "misc": calc.misc
            } for calc in relation_collection
        ]
    })
# Out:
# 100%|██████████| 266/266 [1:24:53<00:00, 19.15s/it]

# %%
np.savez(
    f"{cache_path}/residual_jacobian_calculations__all_sub_toks__{relation_id}__layer_{layer}__approx_rank_{approximate_rank}.npz", 
    jacobians = calculated_relation_collections, 
    allow_pickle = True
)

# %%
calculated_relation_collections = np.load(
    f"{cache_path}/residual_jacobian_calculations__all_sub_toks__{relation_id}__layer_{layer}__approx_rank_{approximate_rank}.npz", 
    allow_pickle = True
)["jacobians"]

# %%
for cur_operators in calculated_relation_collections:
    print("zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz")
    print(f'(s = {cur_operators["request"]["subject"]}, r = {relation} [{relation_id}], o = {cur_operators["request"]["target_true"]["str"]})')
    print("zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz")
    for calc in cur_operators["all_weights_and_biases"]:
        print("----------------------------------------------------------------------------------------------------")
        print(calc["misc"])
        print("----------------------------------------------------------------------------------------------------")

        is_located_in = estimate.RelationOperator(
            model = model, tokenizer= tokenizer,
            layer = layer, relation = relation,
            weight= torch.tensor(calc['weight'], device = model.device), 
            bias= torch.tensor(calc['bias'], device=model.device)
        )

        for subject, subject_token_index, target in test_cases:
            objects = is_located_in(
                subject,
                subject_token_index=subject_token_index,
                device=model.device,
                return_top_k=5,
            )
            print(f"{subject}, target: {target}   ==>   predicted: {objects}")
        print("----------------------------------------------------------------------------------------------------")
        print()
    print()
    print()
# Out:
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Autonomous University of Madrid, r = {} is located in the country of [P17], o = Spain)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3743.695556640625, 'bias_norm': 3783.9189453125, 'h_info': {'h_index': 0, 'token_id': 16541, 'token': 'Aut'}, 'consider_residual': (True, 3, 38.75907516479492)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Niagara Falls, target: Canada   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Valdemarsvik, target: Sweden   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Kyoto University, target: Japan   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Hattfjelldal, target: Norway   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Ginza, target: Japan   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Sydney Hospital, target: Australia   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Mahalangur Himal, target: Nepal   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Higashikagawa, target: Japan   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Trento, target: Italy   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# Taj Mahal, target: India   ==>   predicted: ['atan', ' nine', ' seated', ' situated', 'zar']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 198.92739868164062, 'bias_norm': 388.374267578125, 'h_info': {'h_index': 1, 'token_id': 38175, 'token': 'onomous'}, 'consider_residual': (True, 3, 39.86079025268555)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# Niagara Falls, target: Canada   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Ast']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# Kyoto University, target: Japan   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Madrid']
# Hattfjelldal, target: Norway   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# Ginza, target: Japan   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# Sydney Hospital, target: Australia   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# Higashikagawa, target: Japan   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# Trento, target: Italy   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# Taj Mahal, target: India   ==>   predicted: [' Spain', ' And', ' Gran', ' Catalonia', ' Portugal']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 176.8856201171875, 'bias_norm': 399.5057067871094, 'h_info': {'h_index': 2, 'token_id': 2059, 'token': ' University'}, 'consider_residual': (True, 3, 39.8421516418457)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Niagara Falls, target: Canada   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Kyoto University, target: Japan   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Hattfjelldal, target: Norway   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Ginza, target: Japan   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Sydney Hospital, target: Australia   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Higashikagawa, target: Japan   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Trento, target: Italy   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# Taj Mahal, target: India   ==>   predicted: [' Spain', ' Gran', ' And', ' Catalonia', ' Cast']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 159.23324584960938, 'bias_norm': 385.4372253417969, 'h_info': {'h_index': 3, 'token_id': 286, 'token': ' of'}, 'consider_residual': (True, 3, 40.0181770324707)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Spain', ' And', ' Cast', ' Gran', ' the']
# Niagara Falls, target: Canada   ==>   predicted: [' Spain', ' And', ' Cast', ' Gran', ' the']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Spain', ' And', ' Cast', ' Gran', ' the']
# Kyoto University, target: Japan   ==>   predicted: [' Spain', ' And', ' Cast', ' Gran', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Spain', ' And', ' Cast', ' Gran', ' the']
# Ginza, target: Japan   ==>   predicted: [' Spain', ' And', ' Cast', ' Gran', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' Spain', ' And', ' Cast', ' Gran', ' the']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Spain', ' And', ' Gran', ' Cast', ' the']
# Higashikagawa, target: Japan   ==>   predicted: [' And', ' Spain', ' Cast', ' Gran', ' the']
# Trento, target: Italy   ==>   predicted: [' Spain', ' And', ' Cast', ' Gran', ' the']
# Taj Mahal, target: India   ==>   predicted: [' Spain', ' And', ' Gran', ' Cast', ' the']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 172.57701110839844, 'bias_norm': 394.9103088378906, 'h_info': {'h_index': 4, 'token_id': 14708, 'token': ' Madrid'}, 'consider_residual': (True, 3, 43.37160110473633)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' And', ' Spain', ' Gran', ' the', ' Mal']
# Niagara Falls, target: Canada   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Catalonia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Catalonia']
# Kyoto University, target: Japan   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Mal']
# Hattfjelldal, target: Norway   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Mal']
# Ginza, target: Japan   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Mal']
# Sydney Hospital, target: Australia   ==>   predicted: [' Spain', ' Portugal', ' Gran', ' And', ' Sard']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Spain', ' Gran', ' And', ' the', ' Catalonia']
# Higashikagawa, target: Japan   ==>   predicted: [' Spain', ' And', ' Gran', ' Mal', ' the']
# Trento, target: Italy   ==>   predicted: [' Spain', ' And', ' Gran', ' Mal', ' the']
# Taj Mahal, target: India   ==>   predicted: [' Spain', ' And', ' Gran', ' the', ' Mal']
# ----------------------------------------------------------------------------------------------------
#
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Kuala Langat, r = {} is located in the country of [P17], o = Malaysia)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3741.659423828125, 'bias_norm': 3779.656982421875, 'h_info': {'h_index': 0, 'token_id': 42, 'token': 'K'}, 'consider_residual': (True, 3, 38.722198486328125)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Niagara Falls, target: Canada   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Valdemarsvik, target: Sweden   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Kyoto University, target: Japan   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Hattfjelldal, target: Norway   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Ginza, target: Japan   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Sydney Hospital, target: Australia   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Mahalangur Himal, target: Nepal   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Higashikagawa, target: Japan   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Trento, target: Italy   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# Taj Mahal, target: India   ==>   predicted: ['.', 'itt', 'onia', 'ery', 'aken']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 177.3428955078125, 'bias_norm': 403.7344055175781, 'h_info': {'h_index': 1, 'token_id': 41944, 'token': 'uala'}, 'consider_residual': (True, 3, 42.638736724853516)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Cambodia', ' Brune', ' Vietnam', ' Laos', ' Mal']
# Niagara Falls, target: Canada   ==>   predicted: [' Mal', ' Malaysia', ' Van', ' Brune', ' Sri']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Brune', ' Mal', ' Cambodia', ' Malaysia', ' Laos']
# Kyoto University, target: Japan   ==>   predicted: [' Brune', ' Mal', ' Malaysia', ' Cambodia', ' Vietnam']
# Hattfjelldal, target: Norway   ==>   predicted: [' Mal', ' Brune', ' Malaysia', ' Van', ' B']
# Ginza, target: Japan   ==>   predicted: [' Brune', ' Mal', ' Malaysia', ' Cambodia', ' Sar']
# Sydney Hospital, target: Australia   ==>   predicted: [' Mal', ' Malaysia', ' Brune', ' Singapore', ' Sar']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Vietnam', ' Cambodia', ' Laos', ' Bh', ' Myanmar']
# Higashikagawa, target: Japan   ==>   predicted: [' Mal', ' Brune', ' Malaysia', ' Cambodia', ' Singapore']
# Trento, target: Italy   ==>   predicted: [' Mal', ' Malaysia', ' Brune', ' Van', ' Indonesia']
# Taj Mahal, target: India   ==>   predicted: [' Mal', ' Brune', ' Malaysia', ' B', ' Singapore']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 162.3055877685547, 'bias_norm': 407.3094177246094, 'h_info': {'h_index': 2, 'token_id': 16332, 'token': ' Lang'}, 'consider_residual': (True, 3, 40.0380973815918)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Laos', ' Indonesia']
# Niagara Falls, target: Canada   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Kazakhstan', ' Indonesia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Indonesia', ' Laos']
# Kyoto University, target: Japan   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Indonesia', ' Kazakhstan']
# Hattfjelldal, target: Norway   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Kazakhstan', ' Indonesia']
# Ginza, target: Japan   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Indonesia', ' Laos']
# Sydney Hospital, target: Australia   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Kazakhstan', ' Indonesia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Kazakhstan', ' Indonesia']
# Higashikagawa, target: Japan   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Indonesia', ' Kazakhstan']
# Trento, target: Italy   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Indonesia', ' Kazakhstan']
# Taj Mahal, target: India   ==>   predicted: [' Malaysia', ' Cambodia', ' Brune', ' Kazakhstan', ' Indonesia']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 146.06643676757812, 'bias_norm': 413.4356689453125, 'h_info': {'h_index': 3, 'token_id': 265, 'token': 'at'}, 'consider_residual': (True, 3, 40.12407684326172)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Malaysia', ' Brune', ' Sab', ' Singapore', ' Thailand']
# Niagara Falls, target: Canada   ==>   predicted: [' Malaysia', ' Brune', ' Kazakhstan', ' Myanmar', ' Thailand']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Malaysia', ' Brune', ' Thailand', ' Indonesia', ' Sab']
# Kyoto University, target: Japan   ==>   predicted: [' Malaysia', ' Brune', ' Sab', ' Thailand', ' Indonesia']
# Hattfjelldal, target: Norway   ==>   predicted: [' Malaysia', ' Brune', ' Kazakhstan', ' B', ' Myanmar']
# Ginza, target: Japan   ==>   predicted: [' Malaysia', ' Brune', ' Sab', ' Perl', ' Singapore']
# Sydney Hospital, target: Australia   ==>   predicted: [' Malaysia', ' Brune', ' Sab', ' Singapore', ' Thailand']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Malaysia', ' Brune', ' Kazakhstan', ' Thailand', ' Myanmar']
# Higashikagawa, target: Japan   ==>   predicted: [' Malaysia', ' Brune', ' Sab', ' Thailand', ' B']
# Trento, target: Italy   ==>   predicted: [' Malaysia', ' Brune', ' Sab', ' Thailand', ' B']
# Taj Mahal, target: India   ==>   predicted: [' Malaysia', ' Brune', ' Sab', ' Indonesia', ' Singapore']
# ----------------------------------------------------------------------------------------------------
#
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Bastille, r = {} is located in the country of [P17], o = France)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3871.95849609375, 'bias_norm': 3960.58056640625, 'h_info': {'h_index': 0, 'token_id': 33, 'token': 'B'}, 'consider_residual': (True, 3, 38.89824295043945)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'id']
# Niagara Falls, target: Canada   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'id']
# Valdemarsvik, target: Sweden   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'i']
# Kyoto University, target: Japan   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'id']
# Hattfjelldal, target: Norway   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'i']
# Ginza, target: Japan   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'id']
# Sydney Hospital, target: Australia   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'id']
# Mahalangur Himal, target: Nepal   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'id']
# Higashikagawa, target: Japan   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'id']
# Trento, target: Italy   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'i']
# Taj Mahal, target: India   ==>   predicted: ['é', 'ip', 'ih', 'ern', 'id']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 177.25897216796875, 'bias_norm': 487.737548828125, 'h_info': {'h_index': 1, 'token_id': 459, 'token': 'ast'}, 'consider_residual': (True, 3, 40.44391632080078)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Switzerland']
# Niagara Falls, target: Canada   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Cors']
# Valdemarsvik, target: Sweden   ==>   predicted: [' France', ' Brittany', ' Catalonia', ' Luxembourg', ' Cors']
# Kyoto University, target: Japan   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Switzerland']
# Hattfjelldal, target: Norway   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Cors']
# Ginza, target: Japan   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Cors']
# Sydney Hospital, target: Australia   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Cors']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Switzerland']
# Higashikagawa, target: Japan   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Cors']
# Trento, target: Italy   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Cors']
# Taj Mahal, target: India   ==>   predicted: [' France', ' Brittany', ' Luxembourg', ' Catalonia', ' Cors']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 161.0383758544922, 'bias_norm': 475.0666809082031, 'h_info': {'h_index': 2, 'token_id': 8270, 'token': 'ille'}, 'consider_residual': (True, 3, 41.325843811035156)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' France', ' Brittany', ' Italy', ' Cors', ' the']
# Niagara Falls, target: Canada   ==>   predicted: [' France', ' Brittany', ' Italy', ' Cors', ' Gaul']
# Valdemarsvik, target: Sweden   ==>   predicted: [' France', ' Brittany', ' Gaul', ' the', ' Italy']
# Kyoto University, target: Japan   ==>   predicted: [' France', ' Brittany', ' Italy', ' Cors', ' Georgia']
# Hattfjelldal, target: Norway   ==>   predicted: [' France', ' Brittany', ' the', ' Gaul', ' Bast']
# Ginza, target: Japan   ==>   predicted: [' France', ' Brittany', ' Italy', ' Cors', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' France', ' Georgia', ' Romania', ' Spain', ' Italy']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' France', ' Brittany', ' Georgia', ' Italy', ' the']
# Higashikagawa, target: Japan   ==>   predicted: [' France', ' Brittany', ' Italy', ' Gaul', ' Romania']
# Trento, target: Italy   ==>   predicted: [' Italy', ' Naples', ' France', ' Sicily', ' Spain']
# Taj Mahal, target: India   ==>   predicted: [' France', ' Brittany', ' Cors', ' Italy', ' the']
# ----------------------------------------------------------------------------------------------------
#
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Valdemarsvik, r = {} is located in the country of [P17], o = Sweden)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3905.63818359375, 'bias_norm': 3993.0029296875, 'h_info': {'h_index': 0, 'token_id': 53, 'token': 'V'}, 'consider_residual': (True, 3, 38.714237213134766)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'ub']
# Niagara Falls, target: Canada   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'ub']
# Valdemarsvik, target: Sweden   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'é']
# Kyoto University, target: Japan   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'ub']
# Hattfjelldal, target: Norway   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'é']
# Ginza, target: Japan   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'ub']
# Sydney Hospital, target: Australia   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'ub']
# Mahalangur Himal, target: Nepal   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'ub']
# Higashikagawa, target: Japan   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'ub']
# Trento, target: Italy   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'é']
# Taj Mahal, target: India   ==>   predicted: ['\xad', 'rary', 'onia', 'rial', 'é']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 172.85342407226562, 'bias_norm': 495.6207275390625, 'h_info': {'h_index': 1, 'token_id': 1940, 'token': 'ald'}, 'consider_residual': (True, 3, 40.4617919921875)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Sweden', ' Norway', ' Denmark', ' Iceland', ' Finland']
# Niagara Falls, target: Canada   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Iceland', ' Finland']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Finland', ' Iceland']
# Kyoto University, target: Japan   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Iceland', ' Finland']
# Hattfjelldal, target: Norway   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Iceland', ' Finland']
# Ginza, target: Japan   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Iceland', ' Finland']
# Sydney Hospital, target: Australia   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Iceland', ' Finland']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Sweden', ' Norway', ' Finland', ' Denmark', ' Iceland']
# Higashikagawa, target: Japan   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Iceland', ' Finland']
# Trento, target: Italy   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Iceland', ' Finland']
# Taj Mahal, target: India   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Finland', ' Iceland']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 170.1991424560547, 'bias_norm': 509.8345947265625, 'h_info': {'h_index': 2, 'token_id': 368, 'token': 'em'}, 'consider_residual': (True, 3, 39.95705032348633)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Niagara Falls, target: Canada   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Kyoto University, target: Japan   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Hattfjelldal, target: Norway   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Ginza, target: Japan   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Sydney Hospital, target: Australia   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Higashikagawa, target: Japan   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Trento, target: Italy   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# Taj Mahal, target: India   ==>   predicted: [' Latvia', ' Iceland', ' Norway', ' Sweden', ' Finland']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 141.40899658203125, 'bias_norm': 475.6788330078125, 'h_info': {'h_index': 3, 'token_id': 945, 'token': 'ars'}, 'consider_residual': (True, 3, 40.209388732910156)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Latvia', ' Finland']
# Niagara Falls, target: Canada   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Latvia', ' Finland']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Finland', ' Iceland']
# Kyoto University, target: Japan   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Latvia', ' Finland']
# Hattfjelldal, target: Norway   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Finland', ' Iceland']
# Ginza, target: Japan   ==>   predicted: [' Norway', ' Denmark', ' Sweden', ' Latvia', ' Finland']
# Sydney Hospital, target: Australia   ==>   predicted: [' Norway', ' Sweden', ' Finland', ' Iceland', ' Latvia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Norway', ' Sweden', ' Finland', ' Denmark', ' Iceland']
# Higashikagawa, target: Japan   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Latvia', ' Finland']
# Trento, target: Italy   ==>   predicted: [' Norway', ' Sweden', ' Denmark', ' Latvia', ' Finland']
# Taj Mahal, target: India   ==>   predicted: [' Norway', ' Sweden', ' Finland', ' Denmark', ' Iceland']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 153.85855102539062, 'bias_norm': 464.4398498535156, 'h_info': {'h_index': 4, 'token_id': 28930, 'token': 'vik'}, 'consider_residual': (True, 3, 40.62206268310547)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Sweden', ' Latvia', ' Denmark', ' Estonia', ' Norway']
# Niagara Falls, target: Canada   ==>   predicted: [' Denmark', ' Sweden', ' Norway', ' Latvia', ' Estonia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Sweden', ' Denmark', ' Latvia', ' Estonia', ' Norway']
# Kyoto University, target: Japan   ==>   predicted: [' Sweden', ' Denmark', ' Norway', ' Iceland', ' Finland']
# Hattfjelldal, target: Norway   ==>   predicted: [' Sweden', ' Denmark', ' Norway', ' Latvia', ' Estonia']
# Ginza, target: Japan   ==>   predicted: [' Sweden', ' Denmark', ' Latvia', ' Estonia', ' Norway']
# Sydney Hospital, target: Australia   ==>   predicted: [' Denmark', ' Belgium', ' Luxembourg', ' Latvia', ' Estonia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Sweden', ' Norway', ' Denmark', ' Iceland', ' Russia']
# Higashikagawa, target: Japan   ==>   predicted: [' Latvia', ' Sweden', ' Estonia', ' Denmark', ' Norway']
# Trento, target: Italy   ==>   predicted: [' Sweden', ' Latvia', ' Estonia', ' Denmark', ' Luxembourg']
# Taj Mahal, target: India   ==>   predicted: [' Sweden', ' Denmark', ' Latvia', ' Estonia', ' Norway']
# ----------------------------------------------------------------------------------------------------
#
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Piper Verlag, r = {} is located in the country of [P17], o = Germany)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3903.9169921875, 'bias_norm': 3976.505859375, 'h_info': {'h_index': 0, 'token_id': 47, 'token': 'P'}, 'consider_residual': (True, 3, 38.80953598022461)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Niagara Falls, target: Canada   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Valdemarsvik, target: Sweden   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Kyoto University, target: Japan   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Hattfjelldal, target: Norway   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Ginza, target: Japan   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Sydney Hospital, target: Australia   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Mahalangur Himal, target: Nepal   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Higashikagawa, target: Japan   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Trento, target: Italy   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# Taj Mahal, target: India   ==>   predicted: ['onia', ' unthinkable', 'alia', 'atan', 'asi']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 170.2989501953125, 'bias_norm': 415.6884460449219, 'h_info': {'h_index': 1, 'token_id': 9346, 'token': 'iper'}, 'consider_residual': (True, 3, 39.822444915771484)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Luxembourg', ' Austria', ' Germany', ' Switzerland', ' Lithuania']
# Niagara Falls, target: Canada   ==>   predicted: [' Luxembourg', ' Austria', ' Germany', ' Switzerland', ' Lithuania']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Austria', ' Luxembourg', ' Germany', ' Switzerland', ' Lithuania']
# Kyoto University, target: Japan   ==>   predicted: [' Luxembourg', ' Austria', ' Lithuania', ' Georgia', ' Germany']
# Hattfjelldal, target: Norway   ==>   predicted: [' Austria', ' Luxembourg', ' Germany', ' Switzerland', ' Lithuania']
# Ginza, target: Japan   ==>   predicted: [' Luxembourg', ' Austria', ' Germany', ' Lithuania', ' Switzerland']
# Sydney Hospital, target: Australia   ==>   predicted: [' Luxembourg', ' Austria', ' Germany', ' Switzerland', ' Lithuania']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Luxembourg', ' Austria', ' Lithuania', ' Germany', ' Switzerland']
# Higashikagawa, target: Japan   ==>   predicted: [' Luxembourg', ' Austria', ' Germany', ' Switzerland', ' Lithuania']
# Trento, target: Italy   ==>   predicted: [' Luxembourg', ' Austria', ' Germany', ' Switzerland', ' Lithuania']
# Taj Mahal, target: India   ==>   predicted: [' Austria', ' Luxembourg', ' Germany', ' Switzerland', ' Lithuania']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 172.55783081054688, 'bias_norm': 423.2620544433594, 'h_info': {'h_index': 2, 'token_id': 4643, 'token': ' Ver'}, 'consider_residual': (True, 3, 40.01933288574219)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Denmark', ' Poland']
# Niagara Falls, target: Canada   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Poland', ' Denmark']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Denmark', ' Poland']
# Kyoto University, target: Japan   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Denmark', ' Poland']
# Hattfjelldal, target: Norway   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Poland', ' Hungary']
# Ginza, target: Japan   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Denmark', ' Poland']
# Sydney Hospital, target: Australia   ==>   predicted: [' Germany', ' Luxembourg', ' Poland', ' Lithuania', ' Denmark']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Poland', ' Denmark']
# Higashikagawa, target: Japan   ==>   predicted: [' Germany', ' Luxembourg', ' Poland', ' Lithuania', ' Hungary']
# Trento, target: Italy   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Poland', ' Denmark']
# Taj Mahal, target: India   ==>   predicted: [' Germany', ' Luxembourg', ' Lithuania', ' Poland', ' Denmark']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 167.9636688232422, 'bias_norm': 407.2247009277344, 'h_info': {'h_index': 3, 'token_id': 30909, 'token': 'lag'}, 'consider_residual': (True, 3, 40.19893264770508)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Germany', ' Bav', ' Nam', ' Austria', ' Poland']
# Niagara Falls, target: Canada   ==>   predicted: [' Germany', ' Bav', ' Poland', ' Nam', ' Austria']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Germany', ' Bav', ' Poland', ' Austria', ' Denmark']
# Kyoto University, target: Japan   ==>   predicted: [' Germany', ' Bav', ' Austria', ' Poland', ' Nam']
# Hattfjelldal, target: Norway   ==>   predicted: [' Germany', ' Poland', ' Georgia', ' Bav', ' Nam']
# Ginza, target: Japan   ==>   predicted: [' Germany', ' Bav', ' Nam', ' Austria', ' Poland']
# Sydney Hospital, target: Australia   ==>   predicted: [' Georgia', ' Germany', ' Poland', ' Nam', ' the']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Germany', ' Bav', ' Austria', ' Poland', ' Nam']
# Higashikagawa, target: Japan   ==>   predicted: [' Germany', ' Poland', ' Bav', ' Austria', ' Nam']
# Trento, target: Italy   ==>   predicted: [' Germany', ' Bav', ' Poland', ' Austria', ' Nam']
# Taj Mahal, target: India   ==>   predicted: [' Germany', ' Poland', ' Bav', ' Nam', ' Georgia']
# ----------------------------------------------------------------------------------------------------
#
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Tehri Garhwal district, r = {} is located in the country of [P17], o = India)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3900.126953125, 'bias_norm': 3965.489013671875, 'h_info': {'h_index': 0, 'token_id': 6767, 'token': 'Te'}, 'consider_residual': (True, 3, 38.8796501159668)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Niagara Falls, target: Canada   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Valdemarsvik, target: Sweden   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Kyoto University, target: Japan   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Hattfjelldal, target: Norway   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Ginza, target: Japan   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Sydney Hospital, target: Australia   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Mahalangur Himal, target: Nepal   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Higashikagawa, target: Japan   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Trento, target: Italy   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# Taj Mahal, target: India   ==>   predicted: ['onia', '\xad', 'ud', 'atan', 'alia']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 158.47286987304688, 'bias_norm': 424.20343017578125, 'h_info': {'h_index': 1, 'token_id': 71, 'token': 'h'}, 'consider_residual': (True, 3, 39.956016540527344)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Bangladesh', ' Nepal', ' Afghanistan', ' Bh', ' India']
# Niagara Falls, target: Canada   ==>   predicted: [' Bangladesh', ' Nepal', ' Afghanistan', ' India', ' Bh']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Bangladesh', ' Nepal', ' India', ' Afghanistan', ' Bh']
# Kyoto University, target: Japan   ==>   predicted: [' Bangladesh', ' Nepal', ' India', ' Bh', ' Afghanistan']
# Hattfjelldal, target: Norway   ==>   predicted: [' Bangladesh', ' Nepal', ' Afghanistan', ' India', ' Bh']
# Ginza, target: Japan   ==>   predicted: [' Bangladesh', ' Nepal', ' Afghanistan', ' India', ' Bh']
# Sydney Hospital, target: Australia   ==>   predicted: [' Bangladesh', ' Nepal', ' Afghanistan', ' India', ' Bh']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Bangladesh', ' Nepal', ' Afghanistan', ' India', ' Bh']
# Higashikagawa, target: Japan   ==>   predicted: [' Bangladesh', ' Nepal', ' India', ' Afghanistan', ' Bh']
# Trento, target: Italy   ==>   predicted: [' Bangladesh', ' Nepal', ' Afghanistan', ' India', ' Bh']
# Taj Mahal, target: India   ==>   predicted: [' Bangladesh', ' Nepal', ' Afghanistan', ' India', ' Bh']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 152.5071258544922, 'bias_norm': 403.49853515625, 'h_info': {'h_index': 2, 'token_id': 380, 'token': 'ri'}, 'consider_residual': (True, 3, 39.881404876708984)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' India', ' Nepal', ' Afghanistan', ' Bangladesh', ' Pakistan']
# Niagara Falls, target: Canada   ==>   predicted: [' Nepal', ' India', ' Bangladesh', ' Afghanistan', ' Pakistan']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Nepal', ' India', ' Bangladesh', ' Afghanistan', ' Bh']
# Kyoto University, target: Japan   ==>   predicted: [' Nepal', ' India', ' Bangladesh', ' Afghanistan', ' Pakistan']
# Hattfjelldal, target: Norway   ==>   predicted: [' Nepal', ' India', ' Bangladesh', ' Afghanistan', ' Bh']
# Ginza, target: Japan   ==>   predicted: [' India', ' Nepal', ' Afghanistan', ' Bangladesh', ' Pakistan']
# Sydney Hospital, target: Australia   ==>   predicted: [' Nepal', ' India', ' Bangladesh', ' Afghanistan', ' Pakistan']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Nepal', ' India', ' Bangladesh', ' Afghanistan', ' Utt']
# Higashikagawa, target: Japan   ==>   predicted: [' Nepal', ' India', ' Bangladesh', ' Afghanistan', ' Bh']
# Trento, target: Italy   ==>   predicted: [' India', ' Nepal', ' Afghanistan', ' Bangladesh', ' Pakistan']
# Taj Mahal, target: India   ==>   predicted: [' Nepal', ' India', ' Bangladesh', ' Afghanistan', ' Pakistan']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 165.6121368408203, 'bias_norm': 406.05682373046875, 'h_info': {'h_index': 3, 'token_id': 7164, 'token': ' Gar'}, 'consider_residual': (True, 3, 40.08680725097656)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Nepal', ' Bangladesh', ' India', ' Afghanistan', ' Pakistan']
# Niagara Falls, target: Canada   ==>   predicted: [' Nepal', ' Bangladesh', ' India', ' Afghanistan', ' Pakistan']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Nepal', ' Afghanistan', ' Bangladesh', ' India', ' Pakistan']
# Kyoto University, target: Japan   ==>   predicted: [' Nepal', ' Bangladesh', ' Afghanistan', ' India', ' Pakistan']
# Hattfjelldal, target: Norway   ==>   predicted: [' Nepal', ' Afghanistan', ' Bangladesh', ' India', ' Pakistan']
# Ginza, target: Japan   ==>   predicted: [' Nepal', ' Bangladesh', ' Afghanistan', ' India', ' Pakistan']
# Sydney Hospital, target: Australia   ==>   predicted: [' Nepal', ' Afghanistan', ' Bangladesh', ' India', ' Pakistan']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Nepal', ' Bangladesh', ' Afghanistan', ' India', ' Pakistan']
# Higashikagawa, target: Japan   ==>   predicted: [' Nepal', ' Afghanistan', ' India', ' Bangladesh', ' Pakistan']
# Trento, target: Italy   ==>   predicted: [' Nepal', ' Afghanistan', ' Bangladesh', ' India', ' Pakistan']
# Taj Mahal, target: India   ==>   predicted: [' Nepal', ' Bangladesh', ' Afghanistan', ' India', ' Pakistan']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 151.5363006591797, 'bias_norm': 415.71539306640625, 'h_info': {'h_index': 4, 'token_id': 71, 'token': 'h'}, 'consider_residual': (True, 3, 40.503021240234375)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Pakistan', ' India', ' Afghanistan', ' Nepal', ' Bangladesh']
# Niagara Falls, target: Canada   ==>   predicted: [' India', ' Pakistan', ' Nepal', ' Bangladesh', ' Gujarat']
# Valdemarsvik, target: Sweden   ==>   predicted: [' India', ' Nepal', ' Pakistan', ' Bangladesh', ' Afghanistan']
# Kyoto University, target: Japan   ==>   predicted: [' India', ' Nepal', ' Bangladesh', ' Pakistan', ' Afghanistan']
# Hattfjelldal, target: Norway   ==>   predicted: [' Pakistan', ' India', ' Bangladesh', ' Afghanistan', ' Nepal']
# Ginza, target: Japan   ==>   predicted: [' India', ' Pakistan', ' Nepal', ' Afghanistan', ' Bangladesh']
# Sydney Hospital, target: Australia   ==>   predicted: [' India', ' Pakistan', ' Bangladesh', ' Afghanistan', ' Nepal']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' India', ' Pakistan', ' Nepal', ' Afghanistan', ' Bangladesh']
# Higashikagawa, target: Japan   ==>   predicted: [' India', ' Nepal', ' Bangladesh', ' Pakistan', ' Afghanistan']
# Trento, target: Italy   ==>   predicted: [' India', ' Nepal', ' Pakistan', ' Bangladesh', ' Afghanistan']
# Taj Mahal, target: India   ==>   predicted: [' India', ' Pakistan', ' Nepal', ' Bangladesh', ' Afghanistan']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 141.6886749267578, 'bias_norm': 407.1050720214844, 'h_info': {'h_index': 5, 'token_id': 16783, 'token': 'wal'}, 'consider_residual': (True, 3, 40.47310256958008)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Afghanistan', ' India', ' Pakistan', ' Bangladesh', ' Nepal']
# Niagara Falls, target: Canada   ==>   predicted: [' India', ' Bangladesh', ' Nepal', ' Afghanistan', ' Gujarat']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Afghanistan', ' India', ' Bangladesh', ' Nepal', ' Pakistan']
# Kyoto University, target: Japan   ==>   predicted: [' India', ' Nepal', ' Afghanistan', ' Bangladesh', ' China']
# Hattfjelldal, target: Norway   ==>   predicted: [' Afghanistan', ' Bangladesh', ' Pakistan', ' Nepal', ' India']
# Ginza, target: Japan   ==>   predicted: [' India', ' Afghanistan', ' Bangladesh', ' Nepal', ' Pakistan']
# Sydney Hospital, target: Australia   ==>   predicted: [' Afghanistan', ' Bangladesh', ' Pakistan', ' India', ' Nepal']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' India', ' Afghanistan', ' Bangladesh', ' Nepal', ' Pakistan']
# Higashikagawa, target: Japan   ==>   predicted: [' Bangladesh', ' India', ' Afghanistan', ' Nepal', ' Pakistan']
# Trento, target: Italy   ==>   predicted: [' India', ' Bangladesh', ' Nepal', ' Afghanistan', ' Pakistan']
# Taj Mahal, target: India   ==>   predicted: [' Bangladesh', ' Afghanistan', ' India', ' Pakistan', ' Nepal']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 178.18814086914062, 'bias_norm': 415.3458557128906, 'h_info': {'h_index': 6, 'token_id': 4783, 'token': ' district'}, 'consider_residual': (True, 3, 39.991214752197266)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Niagara Falls, target: Canada   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Valdemarsvik, target: Sweden   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Kyoto University, target: Japan   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Hattfjelldal, target: Norway   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Ginza, target: Japan   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Sydney Hospital, target: Australia   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Higashikagawa, target: Japan   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Trento, target: Italy   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# Taj Mahal, target: India   ==>   predicted: [' India', ' Afghanistan', ' Nepal', ' Pakistan', ' Bh']
# ----------------------------------------------------------------------------------------------------
#
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Darmstadt, r = {} is located in the country of [P17], o = Germany)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3907.090576171875, 'bias_norm': 3969.030029296875, 'h_info': {'h_index': 0, 'token_id': 35, 'token': 'D'}, 'consider_residual': (True, 3, 38.91118621826172)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['enburg', 'é', '\xad', 'ach', 'berg']
# Niagara Falls, target: Canada   ==>   predicted: ['enburg', 'é', '\xad', 'berg', 'ach']
# Valdemarsvik, target: Sweden   ==>   predicted: ['enburg', 'é', '\xad', 'berg', 'ach']
# Kyoto University, target: Japan   ==>   predicted: ['enburg', 'é', '\xad', 'berg', 'ach']
# Hattfjelldal, target: Norway   ==>   predicted: ['enburg', 'é', '\xad', 'berg', 'ach']
# Ginza, target: Japan   ==>   predicted: ['enburg', '\xad', 'é', 'berg', 'ach']
# Sydney Hospital, target: Australia   ==>   predicted: ['enburg', 'é', '\xad', 'berg', 'ach']
# ...
# The Great Wall, target: China   ==>   predicted: [' Switzerland', ' neighboring', ' Austria', ' Geneva', ' Lie']
# Niagara Falls, target: Canada   ==>   predicted: [' Switzerland', ' Austria', ' neighboring', ' Sw', ' Italy']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Switzerland', ' neighboring', ' Lie', ' the', ' Belgium']
# Kyoto University, target: Japan   ==>   predicted: [' Switzerland', ' Geneva', ' neighboring', ' Italy', ' Austria']
# Hattfjelldal, target: Norway   ==>   predicted: [' Switzerland', ' neighboring', ' the', ' Lie', ' Sw']
# Ginza, target: Japan   ==>   predicted: [' Switzerland', ' Sw', ' neighboring', ' Austria', ' Geneva']
# Sydney Hospital, target: Australia   ==>   predicted: [' Switzerland', ' neighboring', ' Lie', ' Geneva', ' the']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Switzerland', ' Austria', ' Italy', ' Bav', ' Ty']
# Higashikagawa, target: Japan   ==>   predicted: [' Switzerland', ' Austria', ' Italy', ' neighboring', ' Geneva']
# Trento, target: Italy   ==>   predicted: [' Switzerland', ' Italy', ' Geneva', ' Austria', ' Spain']
# Taj Mahal, target: India   ==>   predicted: [' Switzerland', ' Austria', ' Geneva', ' neighboring', ' Italy']
# ----------------------------------------------------------------------------------------------------
#
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Tatsuno, r = {} is located in the country of [P17], o = Japan)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3848.593994140625, 'bias_norm': 3935.207763671875, 'h_info': {'h_index': 0, 'token_id': 51, 'token': 'T'}, 'consider_residual': (True, 3, 38.800682067871094)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['iso', 'onia', 'ik', 'é', 'o']
# Niagara Falls, target: Canada   ==>   predicted: ['onia', 'iso', 'ik', 'é', 'o']
# Valdemarsvik, target: Sweden   ==>   predicted: ['onia', 'iso', 'ik', 'é', 'o']
# Kyoto University, target: Japan   ==>   predicted: ['iso', 'onia', 'ik', 'é', 'o']
# Hattfjelldal, target: Norway   ==>   predicted: ['iso', 'onia', 'ik', 'é', 'o']
# Ginza, target: Japan   ==>   predicted: ['iso', 'onia', 'ik', 'é', 'o']
# Sydney Hospital, target: Australia   ==>   predicted: ['onia', 'iso', 'ik', 'é', 'o']
# Mahalangur Himal, target: Nepal   ==>   predicted: ['iso', 'onia', 'ik', 'é', 'o']
# Higashikagawa, target: Japan   ==>   predicted: ['iso', 'onia', 'ik', 'é', 'o']
# Trento, target: Italy   ==>   predicted: ['iso', 'onia', 'ik', 'é', 'o']
# Taj Mahal, target: India   ==>   predicted: ['iso', 'onia', 'ik', 'é', 'o']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 170.6040802001953, 'bias_norm': 500.4824523925781, 'h_info': {'h_index': 1, 'token_id': 1381, 'token': 'ats'}, 'consider_residual': (True, 3, 40.046688079833984)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Kyoto']
# Niagara Falls, target: Canada   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Wak']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Taiwan']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Kyoto', ' Fuk']
# Hattfjelldal, target: Norway   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Taiwan']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Kyoto']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Kyoto']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Wak']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Okinawa', ' Hok', ' Fuk', ' Kyoto']
# Trento, target: Italy   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Wak']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' Hok', ' Okinawa', ' Fuk', ' Kyoto']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 157.67408752441406, 'bias_norm': 519.6453247070312, 'h_info': {'h_index': 2, 'token_id': 36909, 'token': 'uno'}, 'consider_residual': (True, 3, 40.13542938232422)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Japan', ' Georgia', ' South', ' Okinawa', ' the']
# Niagara Falls, target: Canada   ==>   predicted: [' Japan', ' Okinawa', ' Kyoto', ' Ni', ' South']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Japan', ' Okinawa', ' South', ' Georgia', ' Taiwan']
# Kyoto University, target: Japan   ==>   predicted: [' Japan', ' Okinawa', ' Georgia', ' South', ' the']
# Hattfjelldal, target: Norway   ==>   predicted: [' Japan', ' Okinawa', ' South', ' Georgia', ' Taiwan']
# Ginza, target: Japan   ==>   predicted: [' Japan', ' Okinawa', ' Georgia', ' South', ' the']
# Sydney Hospital, target: Australia   ==>   predicted: [' Japan', ' Georgia', ' South', ' Okinawa', ' Finland']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Japan', ' Okinawa', ' South', ' Ni', ' Georgia']
# Higashikagawa, target: Japan   ==>   predicted: [' Japan', ' Georgia', ' South', ' Okinawa', ' Estonia']
# Trento, target: Italy   ==>   predicted: [' Japan', ' Okinawa', ' Georgia', ' South', ' the']
# Taj Mahal, target: India   ==>   predicted: [' Japan', ' Okinawa', ' Georgia', ' South', ' Taiwan']
# ----------------------------------------------------------------------------------------------------
#
#
#
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# (s = Siemiatycze, r = {} is located in the country of [P17], o = Poland)
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 3866.697998046875, 'bias_norm': 3933.989990234375, 'h_info': {'h_index': 0, 'token_id': 50, 'token': 'S'}, 'consider_residual': (True, 3, 38.818939208984375)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: ['ó', 'atan', 'ud', 'iso', 'onia']
# Niagara Falls, target: Canada   ==>   predicted: ['ó', 'atan', 'onia', 'ud', 'iso']
# Valdemarsvik, target: Sweden   ==>   predicted: ['ó', 'atan', 'onia', 'ud', 'iso']
# Kyoto University, target: Japan   ==>   predicted: ['ó', 'atan', 'ud', 'iso', 'onia']
# Hattfjelldal, target: Norway   ==>   predicted: ['ó', 'atan', 'ud', 'onia', 'iso']
# Ginza, target: Japan   ==>   predicted: ['ó', 'atan', 'ud', 'iso', 'onia']
# Sydney Hospital, target: Australia   ==>   predicted: ['ó', 'atan', 'onia', 'ud', 'iso']
# Mahalangur Himal, target: Nepal   ==>   predicted: ['ó', 'atan', 'onia', 'ud', 'iso']
# Higashikagawa, target: Japan   ==>   predicted: ['ó', 'atan', 'ud', 'onia', 'iso']
# Trento, target: Italy   ==>   predicted: ['ó', 'atan', 'onia', 'ud', 'iso']
# Taj Mahal, target: India   ==>   predicted: ['ó', 'atan', 'onia', 'ud', 'iso']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 181.87631225585938, 'bias_norm': 433.5108947753906, 'h_info': {'h_index': 1, 'token_id': 26597, 'token': 'iem'}, 'consider_residual': (True, 3, 40.31178283691406)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovenia']
# Niagara Falls, target: Canada   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovenia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovakia']
# Kyoto University, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovenia']
# Hattfjelldal, target: Norway   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Hungary', ' Slovakia']
# Ginza, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovenia']
# Sydney Hospital, target: Australia   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovakia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovenia']
# Higashikagawa, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Hungary', ' Slovakia']
# Trento, target: Italy   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovakia']
# Taj Mahal, target: India   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Slovenia']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 147.08892822265625, 'bias_norm': 436.70855712890625, 'h_info': {'h_index': 2, 'token_id': 5375, 'token': 'iat'}, 'consider_residual': (True, 3, 40.00935745239258)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Mold', ' Lithuania']
# Niagara Falls, target: Canada   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Mold', ' Lithuania']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Lithuania', ' Mold']
# Kyoto University, target: Japan   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Mold', ' Lithuania']
# Hattfjelldal, target: Norway   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Lithuania', ' Bosnia']
# Ginza, target: Japan   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Mold', ' Lithuania']
# Sydney Hospital, target: Australia   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Lithuania', ' Mold']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Lithuania', ' Mold']
# Higashikagawa, target: Japan   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Lithuania', ' Mold']
# Trento, target: Italy   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Lithuania', ' Mold']
# Taj Mahal, target: India   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Lithuania', ' Mold']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 143.20367431640625, 'bias_norm': 430.9317321777344, 'h_info': {'h_index': 3, 'token_id': 88, 'token': 'y'}, 'consider_residual': (True, 3, 39.935546875)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Hungary', ' Ukraine']
# Niagara Falls, target: Canada   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Bosnia']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Ukraine', ' Mold']
# Kyoto University, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Hungary', ' Mold']
# Hattfjelldal, target: Norway   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Ukraine', ' Hungary']
# Ginza, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Ukraine', ' Hungary']
# Sydney Hospital, target: Australia   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Bosnia']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Hungary', ' Ukraine']
# Higashikagawa, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Hungary', ' Ukraine']
# Trento, target: Italy   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Hungary', ' Ukraine']
# Taj Mahal, target: India   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Hungary', ' Ukraine']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 148.1182098388672, 'bias_norm': 423.043212890625, 'h_info': {'h_index': 4, 'token_id': 66, 'token': 'c'}, 'consider_residual': (True, 3, 40.4516716003418)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Poland', ' Bosnia', ' the', ' Hungary', ' Mold']
# Niagara Falls, target: Canada   ==>   predicted: [' Poland', ' Bosnia', ' Hungary', ' Slovakia', ' Mold']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Poland', ' the', ' Slovakia', ' Belarus', ' Bosnia']
# Kyoto University, target: Japan   ==>   predicted: [' Poland', ' Hungary', ' Bosnia', ' Slovakia', ' Mold']
# Hattfjelldal, target: Norway   ==>   predicted: [' Poland', ' Bosnia', ' the', ' Hungary', ' Mold']
# Ginza, target: Japan   ==>   predicted: [' Poland', ' Bosnia', ' the', ' Slovakia', ' Mold']
# Sydney Hospital, target: Australia   ==>   predicted: [' Poland', ' Georgia', ' Hungary', ' Bosnia', ' Mold']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Poland', ' Hungary', ' Mold', ' Georgia', ' Slovakia']
# Higashikagawa, target: Japan   ==>   predicted: [' Poland', ' Hungary', ' Bosnia', ' Mold', ' the']
# Trento, target: Italy   ==>   predicted: [' Poland', ' Bosnia', ' Hungary', ' Slovakia', ' Gal']
# Taj Mahal, target: India   ==>   predicted: [' Poland', ' Bosnia', ' the', ' Hungary', ' Slovakia']
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# {'Jh_norm': 146.13095092773438, 'bias_norm': 424.5807800292969, 'h_info': {'h_index': 5, 'token_id': 2736, 'token': 'ze'}, 'consider_residual': (True, 3, 42.08436584472656)}
# ----------------------------------------------------------------------------------------------------
# The Great Wall, target: China   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Bosnia', ' Mold']
# Niagara Falls, target: Canada   ==>   predicted: [' Poland', ' Bosnia', ' Hungary', ' Croatia', ' Belarus']
# Valdemarsvik, target: Sweden   ==>   predicted: [' Belarus', ' Poland', ' Lithuania', ' Georgia', ' Ukraine']
# Kyoto University, target: Japan   ==>   predicted: [' Poland', ' Georgia', ' Belarus', ' Bosnia', ' Hungary']
# Hattfjelldal, target: Norway   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Slovakia', ' Bosnia']
# Ginza, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Georgia', ' Bosnia']
# Sydney Hospital, target: Australia   ==>   predicted: [' Poland', ' Belarus', ' Georgia', ' Bosnia', ' Mold']
# Mahalangur Himal, target: Nepal   ==>   predicted: [' Belarus', ' Georgia', ' Poland', ' Mold', ' Bosnia']
# Higashikagawa, target: Japan   ==>   predicted: [' Poland', ' Belarus', ' Hungary', ' Bosnia', ' Georgia']
# Trento, target: Italy   ==>   predicted: [' Poland', ' Bosnia', ' Hungary', ' Georgia', ' Croatia']
# Taj Mahal, target: India   ==>   predicted: [' Poland', ' Belarus', ' Bosnia', ' Georgia', ' Hungary']
# ----------------------------------------------------------------------------------------------------
